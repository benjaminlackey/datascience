# %% [markdown]
# # Scrape mountainproject.com
# This notebook extracts data about climbing routes on mountainproject.com and climbers who have rated those routes. The steps are as follows:
# 1. Use Mountain Project's [route finder](https://www.mountainproject.com/route-guide) to extract all climb's in: New York -> Gunks, The -> Trapps, The. The url's of these routes are given [here](https://www.mountainproject.com/route-finder?selectedIds=105798818&type=rock&diffMinrock=800&diffMinboulder=20000&diffMinaid=70000&diffMinice=30000&diffMinmixed=50000&diffMaxrock=12400&diffMaxboulder=21400&diffMaxaid=75260&diffMaxice=38500&diffMaxmixed=60000&is_trad_climb=1&is_sport_climb=1&is_top_rope=1&stars=0&pitches=0&sort1=area&sort2=rating).
# 2. Go to the page of each route and extract all useful data.
# 3. Go to the ratings page for each route and get each climbers' rating of the route.
# 4. Get all unique climbers that have rated the routes and extract data from their pages.

# %%
# %pylab inline

# Plotting
import matplotlib.pyplot as plt

# Download html of webpage
import urllib2
# Beautiful soup
import bs4 as bs

import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. Extract route urls

# %%
def extract_route_urls(route_table_url, outfile):
    """Take the url for the mountainproject.com table of routes,
    and extract the url for each route.
    """
    source = urllib2.urlopen(route_table_url).read()
    soup = bs.BeautifulSoup(source, 'lxml')

    # All the route urls are repeated twice. Look at the ones in the table only.
    tables = soup.find_all('table')
    route_table = list(tables)[0]
    trs = route_table.find_all('tr')
    routes = [tr.find_all('td') for tr in trs]
    
    nroutes = len(routes)
    
    route_urls = []
    for i in range(nroutes):
        route = routes[i][0]
        s = str(route)
        url = s.split('href="')[1].split('">')[0]
        route_urls.append(url)
        
    df_routes = pd.DataFrame(data=route_urls, columns=['route_url'])
    df_routes.to_csv(outfile, index=False)

# %%
route_table_url = 'https://www.mountainproject.com/route-finder?diffMaxaid=75260&diffMaxboulder=21400&diffMaxice=38500&diffMaxmixed=60000&diffMaxrock=12400&diffMinaid=70000&diffMinboulder=20000&diffMinice=30000&diffMinmixed=50000&diffMinrock=800&is_sport_climb=1&is_top_rope=1&is_trad_climb=1&pitches=0&selectedIds=105798818&sort1=area&sort2=rating&stars=0&type=rock&viewAll=1'
outfile = '../data/route_urls.csv'
extract_route_urls(route_table_url, outfile)

# %%
df_route_urls = pd.read_csv(outfile)
df_route_urls.head(3)
# Out:
#                                                           route_url
# 0      https://www.mountainproject.com/route/108300801/sudoriferous
# 1  https://www.mountainproject.com/route/112109817/cordelette-arete
# 2                https://www.mountainproject.com/route/106133868/69

# %% [markdown]
# # 2. Extract route data

# %%
def extract_route_data(route_url):
    """Extract interesting data from the webpage of a route.
    This is used for building the content based recommender.
    """
    source = urllib2.urlopen(route_url).read()
    soup = bs.BeautifulSoup(source, 'lxml')
    
    # Name of the route
    name_words = soup.find('div', class_='col-md-9 float-md-right').find('h1').text.split()
    route_name = ' '.join(name_words)
    
    # YDS difficulty rating
    difficulty = soup.find('span', class_='rateYDS').text.split()[0]
    
    # Text description of route
    description = soup.find('div', class_='fr-view').text
    
    # protection type, route length, number of pitches
    details = soup.find('table', class_='description-details')
    l = details.find('tr').text.split()
    
    pro_type = str(l[1].replace(',', ''))
    
    # If number of pitches is not stated, there is only 1
    indices = [i for i, s in enumerate(l) if 'pitch'.lower() in s]
    if indices == []:
        pitches = 1
    else:
        pitches = l[indices[0]-1]
    
    # If the word 'ft' does not appear, the length is unknown. Set it to 0 for now.
    indices = [i for i, s in enumerate(l) if 'ft'.lower() in s]
    if indices == []:
        length = 0
    else:
        length = l[indices[0]-1]
    
    
    # Total number of webpage views, monthly views
    l = details.find_all('tr')[2].text.split()
    total_views = int(l[2].replace(',', ''))
    monthly_views = int(l[5].split('/')[0].replace(',', ''))
    
    # Number of route ratings
    l = soup.find('a', class_='show-tooltip').text.split()
    nratings = int(l[-2].replace(',', ''))
    
    return {
        'route_name':route_name, 'difficulty':difficulty, 'description':description, 
        'pro_type':pro_type, 'length':length, 'pitches':pitches,
        'total_views':total_views, 'monthly_views':monthly_views, 
        'nratings':nratings}

# %%
def extract_all_routes_data(route_url_file, route_data_file):
    """Take route urls from a the csv file routes_url_file.
    Extract all the data for each route.
    Save it in the csv file routes_data_file.
    """
    df_routes = pd.read_csv(route_url_file)
    route_urls = df_routes['route_url'].values
    
    route_data_list = []
    nroutes = len(route_urls)
    for i in range(nroutes):
        url = route_urls[i]
        print(i, url)
        data = extract_route_data(url)
        data['iid'] = i
        data['route_url'] = url
        route_data_list.append(data)
    
    df = pd.DataFrame(route_data_list)
    df.to_csv(route_data_file, index=False, encoding='utf-8')

# %%
route_url_file = '../data/route_urls.csv'
route_data_file = '../data/route_data.csv'
extract_all_routes_data(route_url_file, route_data_file)
# Out:
# (0, 'https://www.mountainproject.com/route/108300801/sudoriferous')
# (1, 'https://www.mountainproject.com/route/112109817/cordelette-arete')
# (2, 'https://www.mountainproject.com/route/106133868/69')
# (3, 'https://www.mountainproject.com/route/106437310/easy-keyhole')
# (4, 'https://www.mountainproject.com/route/109528000/short-and-simple')
# (5, 'https://www.mountainproject.com/route/107816567/short-job')
# (6, 'https://www.mountainproject.com/route/105799721/horseman')
# (7, 'https://www.mountainproject.com/route/106133879/no-picnic')
# (8, 'https://www.mountainproject.com/route/106803063/black-fly')
# (9, 'https://www.mountainproject.com/route/106133896/double-chin')
# (10, 'https://www.mountainproject.com/route/105888225/bunny')
# (11, 'https://www.mountainproject.com/route/110494047/pony-express')
# (12, 'https://www.mountainproject.com/route/106133888/fancy-idiot')
# (13, 'https://www.mountainproject.com/route/106138056/eyebrow')
# (14, 'https://www.mountainproject.com/route/106281540/katzenjammer')
# (15, 'https://www.mountainproject.com/route/112279434/the-susie-k-block')
# (16, 'https://www.mountainproject.com/route/106487719/bridal-path')
# (17, 'https://www.mountainproject.com/route/106133727/nice-crack-climb')
# (18, 'https://www.mountainproject.com/route/106395360/the-brat')
# (19, 'https://www.mountainproject.com/route/106395366/handy-andy')
# (20, 'https://www.mountainproject.com/route/106968161/keyhole')
# (21, 'https://www.mountainproject.com/route/106492051/suderiferous-58-variation')
# (22, 'https://www.mountainproject.com/route/106765204/shit-or-go-blind')
# (23, 'https://www.mountainproject.com/route/107074943/herdie-gerdie')
# (24, 'https://www.mountainproject.com/route/112279465/trust-jesus')
# (25, 'https://www.mountainproject.com/route/105846876/dirty-gerdie')
# (26, 'https://www.mountainproject.com/route/106010421/red-cabbage')
# (27, 'https://www.mountainproject.com/route/106570942/lower-eaves')
# (28, 'https://www.mountainproject.com/route/106527113/birthday-biscuit-boy')
# (29, 'https://www.mountainproject.com/route/105840572/apoplexy')
# (30, 'https://www.mountainproject.com/route/106512607/nice-59-climb')
# (31, 'https://www.mountainproject.com/route/113743381/crackatoa')
# (32, 'https://www.mountainproject.com/route/106208196/double-clutch')
# (33, 'https://www.mountainproject.com/route/106589838/red-cabbage-right')
# (34, 'https://www.mountainproject.com/route/107495424/heel-hook-and-hack-it')
# (35, 'https://www.mountainproject.com/route/106410777/sonja')
# (36, 'https://www.mountainproject.com/route/105799032/nosedive')
# (37, 'https://www.mountainproject.com/route/105799038/retribution')
# (38, 'https://www.mountainproject.com/route/114986689/veal-in-a-blender')
# (39, 'https://www.mountainproject.com/route/105840581/coronary')
# (40, 'https://www.mountainproject.com/route/106788807/nurdie-gerdie-aka-dogs-in-heat')
# (41, 'https://www.mountainproject.com/route/108290712/the-executioner-aka-thats-horsesh-tc')
# (42, 'https://www.mountainproject.com/route/106440087/no-solution')
# (43, 'https://www.mountainproject.com/route/108495866/stupid-crack')
# (44, 'https://www.mountainproject.com/route/112903464/zoomulator')
# (45, 'https://www.mountainproject.com/route/112062144/radcliffe-descent')
# (46, 'https://www.mountainproject.com/route/105920873/betty')
# (47, 'https://www.mountainproject.com/route/112377317/back-door-betty')
# (48, 'https://www.mountainproject.com/route/106138089/roddy')
# (49, 'https://www.mountainproject.com/route/113415773/daydream')
# (50, 'https://www.mountainproject.com/route/106101970/belly-roll')
# (51, 'https://www.mountainproject.com/route/105968655/dennis')
# (52, 'https://www.mountainproject.com/route/106134054/rmc')
# (53, 'https://www.mountainproject.com/route/105812940/jackie')
# (54, 'https://www.mountainproject.com/route/111935835/unknown')
# (55, 'https://www.mountainproject.com/route/112849248/big-chimney')
# (56, 'https://www.mountainproject.com/route/106294643/miss-bailey')
# (57, 'https://www.mountainproject.com/route/112279412/his-name-is-called-the-word-of-god')
# (58, 'https://www.mountainproject.com/route/106134067/raubenheimer-special')
# (59, 'https://www.mountainproject.com/route/107134641/pebbles')
# (60, 'https://www.mountainproject.com/route/105812947/classic')
# (61, 'https://www.mountainproject.com/route/106232466/jane')
# (62, 'https://www.mountainproject.com/route/106089252/ape-call')
# (63, 'https://www.mountainproject.com/route/106598640/classy')
# (64, 'https://www.mountainproject.com/route/108167563/jasmine')
# (65, 'https://www.mountainproject.com/route/106134077/the-blackout')
# (66, 'https://www.mountainproject.com/route/111935786/denise')
# (67, 'https://www.mountainproject.com/route/105829266/pink-laurel')
# (68, 'https://www.mountainproject.com/route/106552509/ape-and-essence')
# (69, 'https://www.mountainproject.com/route/106692049/slightly-roddey')
# (70, 'https://www.mountainproject.com/route/111398409/dog-bite-city')
# (71, 'https://www.mountainproject.com/route/105799049/p38')
# (72, 'https://www.mountainproject.com/route/105803228/stirrup-trouble')
# (73, 'https://www.mountainproject.com/route/107506229/badcliff')
# (74, 'https://www.mountainproject.com/route/107134656/510-top-rope')
# (75, 'https://www.mountainproject.com/route/107823141/disco-death-march')
# (76, 'https://www.mountainproject.com/route/105799057/matinee')
# (77, 'https://www.mountainproject.com/route/108089041/a-gape')
# (78, 'https://www.mountainproject.com/route/105803224/into-thin-hair')
# (79, 'https://www.mountainproject.com/route/112555800/cilley-dicken')
# (80, 'https://www.mountainproject.com/route/112302979/word-of-mouth')
# (81, 'https://www.mountainproject.com/route/114201903/creature-features')
# (82, 'https://www.mountainproject.com/route/109626622/habanero-balls')
# (83, 'https://www.mountainproject.com/route/106034654/easy-overhang')
# (84, 'https://www.mountainproject.com/route/105968658/sixish')
# (85, 'https://www.mountainproject.com/route/106227989/arch')
# (86, 'https://www.mountainproject.com/route/107090350/rusty-trifle')
# (87, 'https://www.mountainproject.com/route/106281218/bloody-bush')
# (88, 'https://www.mountainproject.com/route/105799771/frogs-head')
# (89, 'https://www.mountainproject.com/route/105799774/maria')
# (90, 'https://www.mountainproject.com/route/105799782/baby')
# (91, 'https://www.mountainproject.com/route/106101992/wrist')
# (92, 'https://www.mountainproject.com/route/106418188/trusty-rifle')
# (93, 'https://www.mountainproject.com/route/106444608/bloody-mary')
# (94, 'https://www.mountainproject.com/route/109021363/scungilli')
# (95, 'https://www.mountainproject.com/route/108337993/uncle-rudy')
# (96, 'https://www.mountainproject.com/route/105897523/drunkards-delight')
# (97, 'https://www.mountainproject.com/route/105799768/city-lights')
# (98, 'https://www.mountainproject.com/route/108320281/sultana')
# (99, 'https://www.mountainproject.com/route/106444616/morning-after')
# (100, 'https://www.mountainproject.com/route/105821512/son-of-easy-o')
# (101, 'https://www.mountainproject.com/route/106511503/twisted-sister')
# (102, 'https://www.mountainproject.com/route/106010518/sundown')
# (103, 'https://www.mountainproject.com/route/105829283/pas-de-deux')
# (104, 'https://www.mountainproject.com/route/106512347/patty-duke')
# (105, 'https://www.mountainproject.com/route/106565377/arc-of-a-diver')
# (106, 'https://www.mountainproject.com/route/106589844/billy-shears')
# (107, 'https://www.mountainproject.com/route/105828994/maria-direct')
# (108, 'https://www.mountainproject.com/route/106555525/rock-and-brew')
# (109, 'https://www.mountainproject.com/route/106589851/wicks-banana')
# (110, 'https://www.mountainproject.com/route/111539359/rusty-jam')
# (111, 'https://www.mountainproject.com/route/106810025/fetus')
# (112, 'https://www.mountainproject.com/route/106089657/jean')
# (113, 'https://www.mountainproject.com/route/106089667/precarious-perch')
# (114, 'https://www.mountainproject.com/route/106555542/crusty-waffles')
# (115, 'https://www.mountainproject.com/route/107077424/night-fall')
# (116, 'https://www.mountainproject.com/route/108380187/size-matters')
# (117, 'https://www.mountainproject.com/route/107384706/maria-redirect')
# (118, 'https://www.mountainproject.com/route/108247043/kama-sutra')
# (119, 'https://www.mountainproject.com/route/110494043/shockleys-without')
# (120, 'https://www.mountainproject.com/route/105811994/ribs')
# (121, 'https://www.mountainproject.com/route/107852049/simple-ceilings')
# (122, 'https://www.mountainproject.com/route/105954124/high-corner')
# (123, 'https://www.mountainproject.com/route/105799687/shockleys-ceiling')
# (124, 'https://www.mountainproject.com/route/105902104/ribless-aka-spare-ribs')
# (125, 'https://www.mountainproject.com/route/105799704/strictly-from-nowhere')
# (126, 'https://www.mountainproject.com/route/107098017/gorilla-my-dreams')
# (127, 'https://www.mountainproject.com/route/106134457/calisthenic')
# (128, 'https://www.mountainproject.com/route/106295786/oscar-and-charlie')
# (129, 'https://www.mountainproject.com/route/109022777/gaston')
# (130, 'https://www.mountainproject.com/route/106134470/travels-with-charley')
# (131, 'https://www.mountainproject.com/route/106031516/anguish')
# (132, 'https://www.mountainproject.com/route/109555637/glyptodon')
# (133, 'https://www.mountainproject.com/route/106295806/glypnod')
# (134, 'https://www.mountainproject.com/route/107618284/hi-coroner')
# (135, 'https://www.mountainproject.com/route/106089237/grim-ace-face')
# (136, 'https://www.mountainproject.com/route/107395712/midnight-cowboy')
# (137, 'https://www.mountainproject.com/route/106739200/ruby-saturday-direct')
# (138, 'https://www.mountainproject.com/route/105799710/splashtic')
# (139, 'https://www.mountainproject.com/route/108821121/revenge-of-the-relics')
# (140, 'https://www.mountainproject.com/route/106089909/nemesis')
# (141, 'https://www.mountainproject.com/route/113883851/yesterdays-lemonade')
# (142, 'https://www.mountainproject.com/route/108885016/armadillos-delight')
# (143, 'https://www.mountainproject.com/route/109269725/epiclepsy')
# (144, 'https://www.mountainproject.com/route/106078582/pr')
# (145, 'https://www.mountainproject.com/route/111330296/vicious-rumors')
# (146, 'https://www.mountainproject.com/route/105799108/three-pines')
# (147, 'https://www.mountainproject.com/route/105950475/credibility-gap')
# (148, 'https://www.mountainproject.com/route/112278348/lanman-r-idealism')
# (149, 'https://www.mountainproject.com/route/106437414/tequila-mockingbird')
# (150, 'https://www.mountainproject.com/route/106294662/overhanging-layback')
# (151, 'https://www.mountainproject.com/route/106547455/dry-martini')
# (152, 'https://www.mountainproject.com/route/105799118/something-interesting')
# (153, 'https://www.mountainproject.com/route/107694010/co-op')
# (154, 'https://www.mountainproject.com/route/105799128/higher-stannard')
# (155, 'https://www.mountainproject.com/route/106295842/lands-end-direct')
# (156, 'https://www.mountainproject.com/route/109451375/land-ho')
# (157, 'https://www.mountainproject.com/route/107060701/something-boring')
# (158, 'https://www.mountainproject.com/route/105799143/mf')
# (159, 'https://www.mountainproject.com/route/111695378/tough-existence')
# (160, 'https://www.mountainproject.com/route/106281558/men-at-arms')
# (161, 'https://www.mountainproject.com/route/105890675/the-dangler')
# (162, 'https://www.mountainproject.com/route/105799572/tough-shift')
# (163, 'https://www.mountainproject.com/route/106738801/still-crazy-after-all-these-years')
# (164, 'https://www.mountainproject.com/route/105829767/mothers-day-party')
# (165, 'https://www.mountainproject.com/route/105799065/welcome-to-the-gunks')
# (166, 'https://www.mountainproject.com/route/106106801/birdie-party')
# (167, 'https://www.mountainproject.com/route/105803185/star-action')
# (168, 'https://www.mountainproject.com/route/105799088/try-again')
# (169, 'https://www.mountainproject.com/route/106169130/interstice')
# (170, 'https://www.mountainproject.com/route/105799053/coexistence')
# (171, 'https://www.mountainproject.com/route/105799062/graveyard-shift')
# (172, 'https://www.mountainproject.com/route/106138104/scene-of-the-climb')
# (173, 'https://www.mountainproject.com/route/105803234/laughing-man')
# (174, 'https://www.mountainproject.com/route/107821289/fall-to-grace')
# (175, 'https://www.mountainproject.com/route/106763573/fly-again')
# (176, 'https://www.mountainproject.com/route/113734846/girly-man')
# (177, 'https://www.mountainproject.com/route/113150479/impenetrable-ceilings')
# (178, 'https://www.mountainproject.com/route/108270847/the-jane-fonda-workout-for-pregnant-women')
# (179, 'https://www.mountainproject.com/route/113538774/grape-nuts')
# (180, 'https://www.mountainproject.com/route/106139513/willies-weep')
# (181, 'https://www.mountainproject.com/route/105939747/northern-pillar')
# (182, 'https://www.mountainproject.com/route/106139499/twin-oaks')
# (183, 'https://www.mountainproject.com/route/106280313/unamed')
# (184, 'https://www.mountainproject.com/route/106511520/southern-pillar')
# (185, 'https://www.mountainproject.com/route/105801001/beginners-delight')
# (186, 'https://www.mountainproject.com/route/105800326/minty')
# (187, 'https://www.mountainproject.com/route/105800334/tipsy-trees')
# (188, 'https://www.mountainproject.com/route/110451899/dont-shoot')
# (189, 'https://www.mountainproject.com/route/105811979/funny-face')
# (190, 'https://www.mountainproject.com/route/105939730/blueberry-ledges')
# (191, 'https://www.mountainproject.com/route/105810522/triple-bulges')
# (192, 'https://www.mountainproject.com/route/105938062/asphodel')
# (193, 'https://www.mountainproject.com/route/106055576/finger-locks-or-cedar-box')
# (194, 'https://www.mountainproject.com/route/105830332/bitchy-virgin')
# (195, 'https://www.mountainproject.com/route/105806018/hawk')
# (196, 'https://www.mountainproject.com/route/105799697/madame-grunnebaums-wulst')
# (197, 'https://www.mountainproject.com/route/106139522/son-of-bitchy-virgin')
# (198, 'https://www.mountainproject.com/route/114597806/weeping-willie-direct')
# (199, 'https://www.mountainproject.com/route/106285235/immaculate-virgin')
# (200, 'https://www.mountainproject.com/route/106089218/peregrine')
# (201, 'https://www.mountainproject.com/route/111418741/small-furry-mammals-club')
# (202, 'https://www.mountainproject.com/route/107314771/mr-ps-wurst')
# (203, 'https://www.mountainproject.com/route/106139490/columbia')
# (204, 'https://www.mountainproject.com/route/106018730/snookys-return')
# (205, 'https://www.mountainproject.com/route/106089269/bags-end')
# (206, 'https://www.mountainproject.com/route/106134098/hyjeks-horror')
# (207, 'https://www.mountainproject.com/route/105821477/friends-and-lovers')
# (208, 'https://www.mountainproject.com/route/107613265/delusions-of-grandeur')
# (209, 'https://www.mountainproject.com/route/105841807/le-teton')
# (210, 'https://www.mountainproject.com/route/105818020/beatle-brow-bulge')
# (211, 'https://www.mountainproject.com/route/106889345/tetonia')
# (212, 'https://www.mountainproject.com/route/113851850/reach-of-faith')
# (213, 'https://www.mountainproject.com/route/109094670/blueberry-wine')
# (214, 'https://www.mountainproject.com/route/115408331/smegma-garden-and-pigeon')
# (215, 'https://www.mountainproject.com/route/107889373/reds-ruin')
# (216, 'https://www.mountainproject.com/route/108406873/snowpatch')
# (217, 'https://www.mountainproject.com/route/106270916/snake')
# (218, 'https://www.mountainproject.com/route/106143697/wisecrack')
# (219, 'https://www.mountainproject.com/route/105815029/middle-earth')
# (220, 'https://www.mountainproject.com/route/105799785/v-3')
# (221, 'https://www.mountainproject.com/route/105907855/alley-oop')
# (222, 'https://www.mountainproject.com/route/106238205/cakewalk')
# (223, 'https://www.mountainproject.com/route/107037497/bombs-away-dream-baby')
# (224, 'https://www.mountainproject.com/route/105801058/thin-slabs-thin-slabs-direct')
# (225, 'https://www.mountainproject.com/route/105799190/absurdland')
# (226, 'https://www.mountainproject.com/route/113702738/sheep-thrills')
# (227, 'https://www.mountainproject.com/route/106718414/talus-of-powder')
# (228, 'https://www.mountainproject.com/route/105884378/raunchy')
# (229, 'https://www.mountainproject.com/route/106143715/wonderland')
# (230, 'https://www.mountainproject.com/route/106877274/faithful-journey')
# (231, 'https://www.mountainproject.com/route/106495360/dry-heaves')
# (232, 'https://www.mountainproject.com/route/105799187/turdland')
# (233, 'https://www.mountainproject.com/route/105847932/triangle')
# (234, 'https://www.mountainproject.com/route/105841798/sente')
# (235, 'https://www.mountainproject.com/route/106565362/beyond-the-fringe')
# (236, 'https://www.mountainproject.com/route/106146808/gory-thumb')
# (237, 'https://www.mountainproject.com/route/106146816/badfinger')
# (238, 'https://www.mountainproject.com/route/108242249/blunderbus')
# (239, 'https://www.mountainproject.com/route/105920916/commando-rave')
# (240, 'https://www.mountainproject.com/route/112217799/galactic-hitchhikers')
# (241, 'https://www.mountainproject.com/route/106146799/wild-horses')
# (242, 'https://www.mountainproject.com/route/105799095/never-never-land')
# (243, 'https://www.mountainproject.com/route/107466579/nevermore')
# (244, 'https://www.mountainproject.com/route/106189152/city-streets')
# (245, 'https://www.mountainproject.com/route/105920912/balrog')
# (246, 'https://www.mountainproject.com/route/106291093/dis-mantel')
# (247, 'https://www.mountainproject.com/route/107226291/dat-mantel')
# (248, 'https://www.mountainproject.com/route/106046438/jaccuse')
# (249, 'https://www.mountainproject.com/route/109007970/yenta')
# (250, 'https://www.mountainproject.com/route/109172875/cheap-thrills')
# (251, 'https://www.mountainproject.com/route/105799102/never-say-never')
# (252, 'https://www.mountainproject.com/route/112278272/set-my-bow-in-the-cloud')
# (253, 'https://www.mountainproject.com/route/106208236/on-any-monday')
# (254, 'https://www.mountainproject.com/route/106853208/country-roads')
# (255, 'https://www.mountainproject.com/route/107821314/bullfrog')
# (256, 'https://www.mountainproject.com/route/113705603/large-hardon-collider')
# (257, 'https://www.mountainproject.com/route/106009517/easy-verschneidung-easy-v')
# (258, 'https://www.mountainproject.com/route/106511486/andrew')
# (259, 'https://www.mountainproject.com/route/105813398/updraft')
# (260, 'https://www.mountainproject.com/route/105806552/red-pillar')
# (261, 'https://www.mountainproject.com/route/105950518/the-last-will-be-first')
# (262, 'https://www.mountainproject.com/route/105803407/moonlight')
# (263, 'https://www.mountainproject.com/route/111224033/wop-stop')
# (264, 'https://www.mountainproject.com/route/106555418/lost-and-found')
# (265, 'https://www.mountainproject.com/route/105801563/limelight')
# (266, 'https://www.mountainproject.com/route/106046446/hans-puss')
# (267, 'https://www.mountainproject.com/route/106612308/silhouette')
# (268, 'https://www.mountainproject.com/route/106734594/jims-gem')
# (269, 'https://www.mountainproject.com/route/110868757/deep-lichen')
# (270, 'https://www.mountainproject.com/route/105801065/cascading-crystal-kaleidoscope-cck')
# (271, 'https://www.mountainproject.com/route/106862975/moby-dick')
# (272, 'https://www.mountainproject.com/route/105799105/arrow')
# (273, 'https://www.mountainproject.com/route/106739395/diana')
# (274, 'https://www.mountainproject.com/route/106711001/android-moby-dick-link-up')
# (275, 'https://www.mountainproject.com/route/106565353/unholy-wick')
# (276, 'https://www.mountainproject.com/route/105801570/annie-oh')
# (277, 'https://www.mountainproject.com/route/105799085/modern-times')
# (278, 'https://www.mountainproject.com/route/105868264/three-doves')
# (279, 'https://www.mountainproject.com/route/106490427/traverse-of-the-clods')
# (280, 'https://www.mountainproject.com/route/113080646/quiver')
# (281, 'https://www.mountainproject.com/route/105811547/no-glow')
# (282, 'https://www.mountainproject.com/route/106246555/three-vultures')
# (283, 'https://www.mountainproject.com/route/106148512/cold-turkeys')
# (284, 'https://www.mountainproject.com/route/106570961/steep-hikin')
# (285, 'https://www.mountainproject.com/route/105801940/cck-direct')
# (286, 'https://www.mountainproject.com/route/109546911/hawkeye')
# (287, 'https://www.mountainproject.com/route/106089673/proctoscope')
# (288, 'https://www.mountainproject.com/route/106089682/proctor-silex')
# (289, 'https://www.mountainproject.com/route/105826771/keep-on-struttin')
# (290, 'https://www.mountainproject.com/route/106607648/amber-waves-of-pain')
# (291, 'https://www.mountainproject.com/route/106739168/step-lively')
# (292, 'https://www.mountainproject.com/route/106089261/face-to-face')
# (293, 'https://www.mountainproject.com/route/105799568/feast-of-fools')
# (294, 'https://www.mountainproject.com/route/105799041/erect-direction')
# (295, 'https://www.mountainproject.com/route/105799082/nurses-aid')
# (296, 'https://www.mountainproject.com/route/113897838/three-vultures-direct')
# (297, 'https://www.mountainproject.com/route/113639089/strolling-on-jupiter')
# (298, 'https://www.mountainproject.com/route/107771665/mans-quest-for-flight')
# (299, 'https://www.mountainproject.com/route/112426662/crack-n-up')
# (300, 'https://www.mountainproject.com/route/105877392/suppers-ready')
# (301, 'https://www.mountainproject.com/route/115446450/vanishing-point')
# (302, 'https://www.mountainproject.com/route/108002758/smilin-the-hard-way')
# (303, 'https://www.mountainproject.com/route/109555842/twilight-zone')
# (304, 'https://www.mountainproject.com/route/106792907/silly-chimney')
# (305, 'https://www.mountainproject.com/route/109076690/in-the-silly')
# (306, 'https://www.mountainproject.com/route/109526250/third-trapps-chimney')
# (307, 'https://www.mountainproject.com/route/113066452/missing-but-not-lost')
# (308, 'https://www.mountainproject.com/route/106562228/50-50')
# (309, 'https://www.mountainproject.com/route/107381972/first-trapps-chimney')
# (310, 'https://www.mountainproject.com/route/105798994/high-exposure')
# (311, 'https://www.mountainproject.com/route/105840288/ursula')
# (312, 'https://www.mountainproject.com/route/106792623/in-the-groove')
# (313, 'https://www.mountainproject.com/route/106010504/sleepwalk')
# (314, 'https://www.mountainproject.com/route/106579880/lichen-forty-winks')
# (315, 'https://www.mountainproject.com/route/109700137/cool-hand-dukes')
# (316, 'https://www.mountainproject.com/route/106731336/alpine-diversions')
# (317, 'https://www.mountainproject.com/route/110980901/lakatakissima')
# (318, 'https://www.mountainproject.com/route/105828999/groovy')
# (319, 'https://www.mountainproject.com/route/106576675/nose-drops')
# (320, 'https://www.mountainproject.com/route/106598659/insuhlation')
# (321, 'https://www.mountainproject.com/route/105799563/directissima')
# (322, 'https://www.mountainproject.com/route/106148500/obstacle-delusion')
# (323, 'https://www.mountainproject.com/route/105801433/bonnies-roof')
# (324, 'https://www.mountainproject.com/route/105803260/ants-line')
# (325, 'https://www.mountainproject.com/route/106733193/teeny-face')
# (326, 'https://www.mountainproject.com/route/105799077/directississima')
# (327, 'https://www.mountainproject.com/route/105888125/ridicullissima')
# (328, 'https://www.mountainproject.com/route/106232452/ent-line')
# (329, 'https://www.mountainproject.com/route/105841801/space-invaders')
# (330, 'https://www.mountainproject.com/route/107328856/enduro-mans-longest-hangout')
# (331, 'https://www.mountainproject.com/route/106077032/the-throne')
# (332, 'https://www.mountainproject.com/route/109610100/broken-hammer')
# (333, 'https://www.mountainproject.com/route/107866811/49')
# (334, 'https://www.mountainproject.com/route/105800339/48')
# (335, 'https://www.mountainproject.com/route/106789177/full-face-pitch-2-only')
# (336, 'https://www.mountainproject.com/route/112279369/wrath-of-the-lamb')
# (337, 'https://www.mountainproject.com/route/108063699/the-nose')
# (338, 'https://www.mountainproject.com/route/106870148/shit-creek')
# (339, 'https://www.mountainproject.com/route/106554894/ladys-lament-boldville')
# (340, 'https://www.mountainproject.com/route/105806624/bold-ville')
# (341, 'https://www.mountainproject.com/route/106754499/torture-garden')
# (342, 'https://www.mountainproject.com/route/106018758/oblique-twique')
# (343, 'https://www.mountainproject.com/route/106018762/blistered-toe')
# (344, 'https://www.mountainproject.com/route/105806583/double-crack')
# (345, 'https://www.mountainproject.com/route/105806589/airy-aria')
# (346, 'https://www.mountainproject.com/route/106148440/ivan-and-the-saum')
# (347, 'https://www.mountainproject.com/route/106148478/lisa')
# (348, 'https://www.mountainproject.com/route/106554766/fillipina')
# (349, 'https://www.mountainproject.com/route/105814941/ventre-de-boeuf')
# (350, 'https://www.mountainproject.com/route/106739130/los-tres-cabrones')
# (351, 'https://www.mountainproject.com/route/106018746/the-spring-p1')
# (352, 'https://www.mountainproject.com/route/115325123/mona')
# (353, 'https://www.mountainproject.com/route/106733159/high-jinx')
# (354, 'https://www.mountainproject.com/route/106089957/lito-and-the-swan')
# (355, 'https://www.mountainproject.com/route/106813976/lost-in-yellow')
# (356, 'https://www.mountainproject.com/route/113603406/tweak-or-freak')
# (357, 'https://www.mountainproject.com/route/107516922/vader')
# (358, 'https://www.mountainproject.com/route/108813461/manly-yes-but-i-like-it-too')
# (359, 'https://www.mountainproject.com/route/106238729/the-winter')
# (360, 'https://www.mountainproject.com/route/105798933/carbs-and-caffeine')
# (361, 'https://www.mountainproject.com/route/105888230/the-fall')
# (362, 'https://www.mountainproject.com/route/105798938/no-mans-land')
# (363, 'https://www.mountainproject.com/route/105798924/the-yellow-wall')
# (364, 'https://www.mountainproject.com/route/105898985/the-sting')
# (365, 'https://www.mountainproject.com/route/106948350/the-summer')
# (366, 'https://www.mountainproject.com/route/112426725/dissonance')
# (367, 'https://www.mountainproject.com/route/108002791/tiers-of-fear')
# (368, 'https://www.mountainproject.com/route/106076954/uphill-all-the-way-aka-the-man-who-fell-to-earth')
# (369, 'https://www.mountainproject.com/route/111291062/wasp-stop')
# (370, 'https://www.mountainproject.com/route/106389128/scary-area')
# (371, 'https://www.mountainproject.com/route/113624593/prick-the')
# (372, 'https://www.mountainproject.com/route/109528142/the-blue-stink')
# (373, 'https://www.mountainproject.com/route/111281525/sticky-gate')
# (374, 'https://www.mountainproject.com/route/111281627/raindance')
# (375, 'https://www.mountainproject.com/route/107037481/sundance')
# (376, 'https://www.mountainproject.com/route/107037493/moondance')
# (377, 'https://www.mountainproject.com/route/110360975/hooky')
# (378, 'https://www.mountainproject.com/route/107397712/sticky-gate-with-direct-finish')
# (379, 'https://www.mountainproject.com/route/106569152/tangled-up-and-blue')
# (380, 'https://www.mountainproject.com/route/105830801/wasp')
# (381, 'https://www.mountainproject.com/route/110386969/coprophagia')
# (382, 'https://www.mountainproject.com/route/105818206/simple-suff')
# (383, 'https://www.mountainproject.com/route/105799072/falled-on-account-of-strain')
# (384, 'https://www.mountainproject.com/route/106657433/last-frontier')
# (385, 'https://www.mountainproject.com/route/108252898/back-to-the-future-aka-jap')
# (386, 'https://www.mountainproject.com/route/105824824/frustration-syndrome')
# (387, 'https://www.mountainproject.com/route/106395672/bragg-hatch')
# (388, 'https://www.mountainproject.com/route/107357222/golden-showers')
# (389, 'https://www.mountainproject.com/route/106077540/the-stand')
# (390, 'https://www.mountainproject.com/route/107342001/april-showers')
# (391, 'https://www.mountainproject.com/route/106077545/comedy-in-three-acts')
# (392, 'https://www.mountainproject.com/route/108430321/climb-and-punishment')
# (393, 'https://www.mountainproject.com/route/107486305/kligfields-follies')
# (394, 'https://www.mountainproject.com/route/107797205/techno-suff')
# (395, 'https://www.mountainproject.com/route/113015330/that-thing')
# (396, 'https://www.mountainproject.com/route/114129141/drop-zone')
# (397, 'https://www.mountainproject.com/route/110849183/wet-dream')
# (398, 'https://www.mountainproject.com/route/113450673/pressure-drop')
# (399, 'https://www.mountainproject.com/route/109610469/rogers-escape-hatch')
# (400, 'https://www.mountainproject.com/route/106146834/the-lone-ranger')
# (401, 'https://www.mountainproject.com/route/109527979/four-foot-face')
# (402, 'https://www.mountainproject.com/route/105800896/casa-emilio')
# (403, 'https://www.mountainproject.com/route/109161193/pfui-teufel')
# (404, 'https://www.mountainproject.com/route/106554245/a-long-walk-for-man-a-short-climb-for-mankind')
# (405, 'https://www.mountainproject.com/route/109077172/emilietta')
# (406, 'https://www.mountainproject.com/route/108388344/crack-of-despondency')
# (407, 'https://www.mountainproject.com/route/111807940/rangers-revenge')
# (408, 'https://www.mountainproject.com/route/105972375/trigger-point')
# (409, 'https://www.mountainproject.com/route/108197328/dicks-prick')
# (410, 'https://www.mountainproject.com/route/107308180/penal-colonycircumcision-link-up')
# (411, 'https://www.mountainproject.com/route/111787942/emilio')
# (412, 'https://www.mountainproject.com/route/106395422/almost-pure-and-simple')
# (413, 'https://www.mountainproject.com/route/106551414/footloose')
# (414, 'https://www.mountainproject.com/route/106550688/fancy-free')
# (415, 'https://www.mountainproject.com/route/105825882/casablanca')
# (416, 'https://www.mountainproject.com/route/106395410/counterstrike')
# (417, 'https://www.mountainproject.com/route/106435212/arts-route')
# (418, 'https://www.mountainproject.com/route/111064796/the-devil-made-me-do-it')
# (419, 'https://www.mountainproject.com/route/106604512/casanova')
# (420, 'https://www.mountainproject.com/route/106395393/wegetables-ive-never-seen-before')
# (421, 'https://www.mountainproject.com/route/107303463/vd')
# (422, 'https://www.mountainproject.com/route/106395385/boron-destroyer')
# (423, 'https://www.mountainproject.com/route/106089227/creaky-joints-and-trigger-points')
# (424, 'https://www.mountainproject.com/route/106774183/headless-horseman')
# (425, 'https://www.mountainproject.com/route/106214631/tennish-anyone')
# (426, 'https://www.mountainproject.com/route/106598679/independent-hangover')
# (427, 'https://www.mountainproject.com/route/105799068/10000-restless-virgins')
# (428, 'https://www.mountainproject.com/route/111064746/meat-by-products')
# (429, 'https://www.mountainproject.com/route/114933479/slime-world')
# (430, 'https://www.mountainproject.com/route/111059966/future-shock')
# (431, 'https://www.mountainproject.com/route/111476310/bone-hard')
# (432, 'https://www.mountainproject.com/route/106520369/uberfall-descent')
# (433, 'https://www.mountainproject.com/route/106134047/crimson-corner')
# (434, 'https://www.mountainproject.com/route/106511488/dirty-chimney')
# (435, 'https://www.mountainproject.com/route/107204503/the-flake')
# (436, 'https://www.mountainproject.com/route/112109828/wriggles')
# (437, 'https://www.mountainproject.com/route/106866202/das-wiggles')
# (438, 'https://www.mountainproject.com/route/106099552/harvard')
# (439, 'https://www.mountainproject.com/route/109149831/yale')
# (440, 'https://www.mountainproject.com/route/110512387/the-star-route')
# (441, 'https://www.mountainproject.com/route/106133962/squiggles')
# (442, 'https://www.mountainproject.com/route/106031901/boston')
# (443, 'https://www.mountainproject.com/route/111133222/crowberry-ridge')
# (444, 'https://www.mountainproject.com/route/113805195/penn')
# (445, 'https://www.mountainproject.com/route/108445716/eyesore')
# (446, 'https://www.mountainproject.com/route/105810485/rhododendron')
# (447, 'https://www.mountainproject.com/route/105810464/laurel')
# (448, 'https://www.mountainproject.com/route/106176598/cc-route')
# (449, 'https://www.mountainproject.com/route/107282255/clover')
# (450, 'https://www.mountainproject.com/route/105799779/kens-crack')
# (451, 'https://www.mountainproject.com/route/106034638/trapped-like-a-rat')
# (452, 'https://www.mountainproject.com/route/113116195/no-pro')
# (453, 'https://www.mountainproject.com/route/106587817/fitschens-folly')
# (454, 'https://www.mountainproject.com/route/106134040/bb-route')
# (455, 'https://www.mountainproject.com/route/107081330/mitty-mouse')
# (456, 'https://www.mountainproject.com/route/106133976/walter-mitty')
# (457, 'https://www.mountainproject.com/route/106208732/junior')
# (458, 'https://www.mountainproject.com/route/106581984/charie')
# (459, 'https://www.mountainproject.com/route/107524902/dd-route')
# (460, 'https://www.mountainproject.com/route/106138061/squiggles-direct')
# (461, 'https://www.mountainproject.com/route/106138074/jacobs-ladder')
# (462, 'https://www.mountainproject.com/route/109672957/unknown-aka-ken-and-the-art-of-motorcycle-maintenance')
# (463, 'https://www.mountainproject.com/route/105855228/phoebe')
# (464, 'https://www.mountainproject.com/route/111864229/birch')
# (465, 'https://www.mountainproject.com/route/106133985/susie-a')
# (466, 'https://www.mountainproject.com/route/109055246/shitty-mitty')
# (467, 'https://www.mountainproject.com/route/106640673/hudsons-boulder-problem-aka-trashcan-overhang')
# (468, 'https://www.mountainproject.com/route/106456276/low-exposure')
# (469, 'https://www.mountainproject.com/route/112930386/freebie')

# %%
df_routes = pd.read_csv(route_data_file)

df_routes.head(2)
# Out:
#                                                                                            description  \
# 0  Pitch 1: Climb the face just next to the huge left-facing corner (feel free to use the corner bl...
# 1  The first* route in the Trapps! An easy jaunt up a sharp arete, and surprisingly airy for a such...
#
#   difficulty  iid  length  monthly_views  nratings  pitches pro_type  \
# 0        5.2    0     120             19         7        2     Trad
# 1        5.2    1      80             38        12        1     Trad
#
#          route_name  \
# 0      Sudoriferous
# 1  Cordelette Arete
#
#                                                           route_url  \
# 0      https://www.mountainproject.com/route/108300801/sudoriferous
# 1  https://www.mountainproject.com/route/112109817/cordelette-arete
#
#    total_views
# 0         1309
# 1         1161

# %% [markdown]
# # 3. Extract the ratings for each route

# %%
def extract_route_ratings(route_url):
    """Get all available users' ratings for the route.
    """
    # Website with the rating stats corresponding to route_url
    pieces = route_url.split('/')
    url = 'https://www.mountainproject.com/route/stats/{}/{}'.format(
        pieces[-2], pieces[-1])
    
    source = urllib2.urlopen(url).read()
    soup = bs.BeautifulSoup(source, 'lxml')
    
    # Each row of this table contains the user and number of stars
    rows = soup.find('table', class_='table table-striped').find_all('tr')
    nrows = len(rows)
    
    ratings = []
    for i in range(nrows):
        # Table row
        tr = rows[i]
        user_url = tr.find('a').get('href')
        # Each star is an image. Count the number of them.
        # A bomb image is the same as counting 0 stars.
        images = tr.find_all('img')
        images = [i.get('src') for i in images]
        star_img = 'https://cdn.apstatic.com/img/stars/starBlue.svg'
        nstars = images.count(star_img)
        d = {'user_url':user_url, 'route_url':route_url, 'rating':nstars}
        ratings.append(d)
        
    return ratings

# %%
def extract_ratings_for_all_routes(route_url_file, ratings_file):
    """Take route urls from a the csv file route_url_file.
    Extract the ratings for all of the routes.
    Save it in the csv file ratings_file.
    """
    df_routes = pd.read_csv(route_url_file)
    route_urls = df_routes['route_url'].values
    
    ratings_all_routes = []
    nroutes = len(route_urls)
    for i in range(nroutes):
        url = route_urls[i]
        print(i, url)
        ratings = extract_route_ratings(url)
        # Concatenate lists. Don't make a list of lists by appending.
        ratings_all_routes += ratings
        
    df = pd.DataFrame(ratings_all_routes)
    df.to_csv(ratings_file, index=False)

# %%
route_url_file = '../data/route_urls.csv'
ratings_file = '../data/route_ratings.csv'
extract_ratings_for_all_routes(route_url_file, ratings_file)
# Out:
# (0, 'https://www.mountainproject.com/route/108300801/sudoriferous')
# (1, 'https://www.mountainproject.com/route/112109817/cordelette-arete')
# (2, 'https://www.mountainproject.com/route/106133868/69')
# (3, 'https://www.mountainproject.com/route/106437310/easy-keyhole')
# (4, 'https://www.mountainproject.com/route/109528000/short-and-simple')
# (5, 'https://www.mountainproject.com/route/107816567/short-job')
# (6, 'https://www.mountainproject.com/route/105799721/horseman')
# (7, 'https://www.mountainproject.com/route/106133879/no-picnic')
# (8, 'https://www.mountainproject.com/route/106803063/black-fly')
# (9, 'https://www.mountainproject.com/route/106133896/double-chin')
# (10, 'https://www.mountainproject.com/route/105888225/bunny')
# (11, 'https://www.mountainproject.com/route/110494047/pony-express')
# (12, 'https://www.mountainproject.com/route/106133888/fancy-idiot')
# (13, 'https://www.mountainproject.com/route/106138056/eyebrow')
# (14, 'https://www.mountainproject.com/route/106281540/katzenjammer')
# (15, 'https://www.mountainproject.com/route/112279434/the-susie-k-block')
# (16, 'https://www.mountainproject.com/route/106487719/bridal-path')
# (17, 'https://www.mountainproject.com/route/106133727/nice-crack-climb')
# (18, 'https://www.mountainproject.com/route/106395360/the-brat')
# (19, 'https://www.mountainproject.com/route/106395366/handy-andy')
# (20, 'https://www.mountainproject.com/route/106968161/keyhole')
# (21, 'https://www.mountainproject.com/route/106492051/suderiferous-58-variation')
# (22, 'https://www.mountainproject.com/route/106765204/shit-or-go-blind')
# (23, 'https://www.mountainproject.com/route/107074943/herdie-gerdie')
# (24, 'https://www.mountainproject.com/route/112279465/trust-jesus')
# (25, 'https://www.mountainproject.com/route/105846876/dirty-gerdie')
# (26, 'https://www.mountainproject.com/route/106010421/red-cabbage')
# (27, 'https://www.mountainproject.com/route/106570942/lower-eaves')
# (28, 'https://www.mountainproject.com/route/106527113/birthday-biscuit-boy')
# (29, 'https://www.mountainproject.com/route/105840572/apoplexy')
# (30, 'https://www.mountainproject.com/route/106512607/nice-59-climb')
# (31, 'https://www.mountainproject.com/route/113743381/crackatoa')
# (32, 'https://www.mountainproject.com/route/106208196/double-clutch')
# (33, 'https://www.mountainproject.com/route/106589838/red-cabbage-right')
# (34, 'https://www.mountainproject.com/route/107495424/heel-hook-and-hack-it')
# (35, 'https://www.mountainproject.com/route/106410777/sonja')
# (36, 'https://www.mountainproject.com/route/105799032/nosedive')
# (37, 'https://www.mountainproject.com/route/105799038/retribution')
# (38, 'https://www.mountainproject.com/route/114986689/veal-in-a-blender')
# (39, 'https://www.mountainproject.com/route/105840581/coronary')
# (40, 'https://www.mountainproject.com/route/106788807/nurdie-gerdie-aka-dogs-in-heat')
# (41, 'https://www.mountainproject.com/route/108290712/the-executioner-aka-thats-horsesh-tc')
# (42, 'https://www.mountainproject.com/route/106440087/no-solution')
# (43, 'https://www.mountainproject.com/route/108495866/stupid-crack')
# (44, 'https://www.mountainproject.com/route/112903464/zoomulator')
# (45, 'https://www.mountainproject.com/route/112062144/radcliffe-descent')
# (46, 'https://www.mountainproject.com/route/105920873/betty')
# (47, 'https://www.mountainproject.com/route/112377317/back-door-betty')
# (48, 'https://www.mountainproject.com/route/106138089/roddy')
# (49, 'https://www.mountainproject.com/route/113415773/daydream')
# (50, 'https://www.mountainproject.com/route/106101970/belly-roll')
# (51, 'https://www.mountainproject.com/route/105968655/dennis')
# (52, 'https://www.mountainproject.com/route/106134054/rmc')
# (53, 'https://www.mountainproject.com/route/105812940/jackie')
# (54, 'https://www.mountainproject.com/route/111935835/unknown')
# (55, 'https://www.mountainproject.com/route/112849248/big-chimney')
# (56, 'https://www.mountainproject.com/route/106294643/miss-bailey')
# (57, 'https://www.mountainproject.com/route/112279412/his-name-is-called-the-word-of-god')
# (58, 'https://www.mountainproject.com/route/106134067/raubenheimer-special')
# (59, 'https://www.mountainproject.com/route/107134641/pebbles')
# (60, 'https://www.mountainproject.com/route/105812947/classic')
# (61, 'https://www.mountainproject.com/route/106232466/jane')
# (62, 'https://www.mountainproject.com/route/106089252/ape-call')
# (63, 'https://www.mountainproject.com/route/106598640/classy')
# (64, 'https://www.mountainproject.com/route/108167563/jasmine')
# (65, 'https://www.mountainproject.com/route/106134077/the-blackout')
# (66, 'https://www.mountainproject.com/route/111935786/denise')
# (67, 'https://www.mountainproject.com/route/105829266/pink-laurel')
# (68, 'https://www.mountainproject.com/route/106552509/ape-and-essence')
# (69, 'https://www.mountainproject.com/route/106692049/slightly-roddey')
# (70, 'https://www.mountainproject.com/route/111398409/dog-bite-city')
# (71, 'https://www.mountainproject.com/route/105799049/p38')
# (72, 'https://www.mountainproject.com/route/105803228/stirrup-trouble')
# (73, 'https://www.mountainproject.com/route/107506229/badcliff')
# (74, 'https://www.mountainproject.com/route/107134656/510-top-rope')
# (75, 'https://www.mountainproject.com/route/107823141/disco-death-march')
# (76, 'https://www.mountainproject.com/route/105799057/matinee')
# (77, 'https://www.mountainproject.com/route/108089041/a-gape')
# (78, 'https://www.mountainproject.com/route/105803224/into-thin-hair')
# (79, 'https://www.mountainproject.com/route/112555800/cilley-dicken')
# (80, 'https://www.mountainproject.com/route/112302979/word-of-mouth')
# (81, 'https://www.mountainproject.com/route/114201903/creature-features')
# (82, 'https://www.mountainproject.com/route/109626622/habanero-balls')
# (83, 'https://www.mountainproject.com/route/106034654/easy-overhang')
# (84, 'https://www.mountainproject.com/route/105968658/sixish')
# (85, 'https://www.mountainproject.com/route/106227989/arch')
# (86, 'https://www.mountainproject.com/route/107090350/rusty-trifle')
# (87, 'https://www.mountainproject.com/route/106281218/bloody-bush')
# (88, 'https://www.mountainproject.com/route/105799771/frogs-head')
# (89, 'https://www.mountainproject.com/route/105799774/maria')
# (90, 'https://www.mountainproject.com/route/105799782/baby')
# (91, 'https://www.mountainproject.com/route/106101992/wrist')
# (92, 'https://www.mountainproject.com/route/106418188/trusty-rifle')
# (93, 'https://www.mountainproject.com/route/106444608/bloody-mary')
# (94, 'https://www.mountainproject.com/route/109021363/scungilli')
# (95, 'https://www.mountainproject.com/route/108337993/uncle-rudy')
# (96, 'https://www.mountainproject.com/route/105897523/drunkards-delight')
# (97, 'https://www.mountainproject.com/route/105799768/city-lights')
# (98, 'https://www.mountainproject.com/route/108320281/sultana')
# (99, 'https://www.mountainproject.com/route/106444616/morning-after')
# (100, 'https://www.mountainproject.com/route/105821512/son-of-easy-o')
# (101, 'https://www.mountainproject.com/route/106511503/twisted-sister')
# (102, 'https://www.mountainproject.com/route/106010518/sundown')
# (103, 'https://www.mountainproject.com/route/105829283/pas-de-deux')
# (104, 'https://www.mountainproject.com/route/106512347/patty-duke')
# (105, 'https://www.mountainproject.com/route/106565377/arc-of-a-diver')
# (106, 'https://www.mountainproject.com/route/106589844/billy-shears')
# (107, 'https://www.mountainproject.com/route/105828994/maria-direct')
# (108, 'https://www.mountainproject.com/route/106555525/rock-and-brew')
# (109, 'https://www.mountainproject.com/route/106589851/wicks-banana')
# (110, 'https://www.mountainproject.com/route/111539359/rusty-jam')
# (111, 'https://www.mountainproject.com/route/106810025/fetus')
# (112, 'https://www.mountainproject.com/route/106089657/jean')
# (113, 'https://www.mountainproject.com/route/106089667/precarious-perch')
# (114, 'https://www.mountainproject.com/route/106555542/crusty-waffles')
# (115, 'https://www.mountainproject.com/route/107077424/night-fall')
# (116, 'https://www.mountainproject.com/route/108380187/size-matters')
# (117, 'https://www.mountainproject.com/route/107384706/maria-redirect')
# (118, 'https://www.mountainproject.com/route/108247043/kama-sutra')
# (119, 'https://www.mountainproject.com/route/110494043/shockleys-without')
# (120, 'https://www.mountainproject.com/route/105811994/ribs')
# (121, 'https://www.mountainproject.com/route/107852049/simple-ceilings')
# (122, 'https://www.mountainproject.com/route/105954124/high-corner')
# (123, 'https://www.mountainproject.com/route/105799687/shockleys-ceiling')
# (124, 'https://www.mountainproject.com/route/105902104/ribless-aka-spare-ribs')
# (125, 'https://www.mountainproject.com/route/105799704/strictly-from-nowhere')
# (126, 'https://www.mountainproject.com/route/107098017/gorilla-my-dreams')
# (127, 'https://www.mountainproject.com/route/106134457/calisthenic')
# (128, 'https://www.mountainproject.com/route/106295786/oscar-and-charlie')
# (129, 'https://www.mountainproject.com/route/109022777/gaston')
# (130, 'https://www.mountainproject.com/route/106134470/travels-with-charley')
# (131, 'https://www.mountainproject.com/route/106031516/anguish')
# (132, 'https://www.mountainproject.com/route/109555637/glyptodon')
# (133, 'https://www.mountainproject.com/route/106295806/glypnod')
# (134, 'https://www.mountainproject.com/route/107618284/hi-coroner')
# (135, 'https://www.mountainproject.com/route/106089237/grim-ace-face')
# (136, 'https://www.mountainproject.com/route/107395712/midnight-cowboy')
# (137, 'https://www.mountainproject.com/route/106739200/ruby-saturday-direct')
# (138, 'https://www.mountainproject.com/route/105799710/splashtic')
# (139, 'https://www.mountainproject.com/route/108821121/revenge-of-the-relics')
# (140, 'https://www.mountainproject.com/route/106089909/nemesis')
# (141, 'https://www.mountainproject.com/route/113883851/yesterdays-lemonade')
# (142, 'https://www.mountainproject.com/route/108885016/armadillos-delight')
# (143, 'https://www.mountainproject.com/route/109269725/epiclepsy')
# (144, 'https://www.mountainproject.com/route/106078582/pr')
# (145, 'https://www.mountainproject.com/route/111330296/vicious-rumors')
# (146, 'https://www.mountainproject.com/route/105799108/three-pines')
# (147, 'https://www.mountainproject.com/route/105950475/credibility-gap')
# (148, 'https://www.mountainproject.com/route/112278348/lanman-r-idealism')
# (149, 'https://www.mountainproject.com/route/106437414/tequila-mockingbird')
# (150, 'https://www.mountainproject.com/route/106294662/overhanging-layback')
# (151, 'https://www.mountainproject.com/route/106547455/dry-martini')
# (152, 'https://www.mountainproject.com/route/105799118/something-interesting')
# (153, 'https://www.mountainproject.com/route/107694010/co-op')
# (154, 'https://www.mountainproject.com/route/105799128/higher-stannard')
# (155, 'https://www.mountainproject.com/route/106295842/lands-end-direct')
# (156, 'https://www.mountainproject.com/route/109451375/land-ho')
# (157, 'https://www.mountainproject.com/route/107060701/something-boring')
# (158, 'https://www.mountainproject.com/route/105799143/mf')
# (159, 'https://www.mountainproject.com/route/111695378/tough-existence')
# (160, 'https://www.mountainproject.com/route/106281558/men-at-arms')
# (161, 'https://www.mountainproject.com/route/105890675/the-dangler')
# (162, 'https://www.mountainproject.com/route/105799572/tough-shift')
# (163, 'https://www.mountainproject.com/route/106738801/still-crazy-after-all-these-years')
# (164, 'https://www.mountainproject.com/route/105829767/mothers-day-party')
# (165, 'https://www.mountainproject.com/route/105799065/welcome-to-the-gunks')
# (166, 'https://www.mountainproject.com/route/106106801/birdie-party')
# (167, 'https://www.mountainproject.com/route/105803185/star-action')
# (168, 'https://www.mountainproject.com/route/105799088/try-again')
# (169, 'https://www.mountainproject.com/route/106169130/interstice')
# (170, 'https://www.mountainproject.com/route/105799053/coexistence')
# (171, 'https://www.mountainproject.com/route/105799062/graveyard-shift')
# (172, 'https://www.mountainproject.com/route/106138104/scene-of-the-climb')
# (173, 'https://www.mountainproject.com/route/105803234/laughing-man')
# (174, 'https://www.mountainproject.com/route/107821289/fall-to-grace')
# (175, 'https://www.mountainproject.com/route/106763573/fly-again')
# (176, 'https://www.mountainproject.com/route/113734846/girly-man')
# (177, 'https://www.mountainproject.com/route/113150479/impenetrable-ceilings')
# (178, 'https://www.mountainproject.com/route/108270847/the-jane-fonda-workout-for-pregnant-women')
# (179, 'https://www.mountainproject.com/route/113538774/grape-nuts')
# (180, 'https://www.mountainproject.com/route/106139513/willies-weep')
# (181, 'https://www.mountainproject.com/route/105939747/northern-pillar')
# (182, 'https://www.mountainproject.com/route/106139499/twin-oaks')
# (183, 'https://www.mountainproject.com/route/106280313/unamed')
# (184, 'https://www.mountainproject.com/route/106511520/southern-pillar')
# (185, 'https://www.mountainproject.com/route/105801001/beginners-delight')
# (186, 'https://www.mountainproject.com/route/105800326/minty')
# (187, 'https://www.mountainproject.com/route/105800334/tipsy-trees')
# (188, 'https://www.mountainproject.com/route/110451899/dont-shoot')
# (189, 'https://www.mountainproject.com/route/105811979/funny-face')
# (190, 'https://www.mountainproject.com/route/105939730/blueberry-ledges')
# (191, 'https://www.mountainproject.com/route/105810522/triple-bulges')
# (192, 'https://www.mountainproject.com/route/105938062/asphodel')
# (193, 'https://www.mountainproject.com/route/106055576/finger-locks-or-cedar-box')
# (194, 'https://www.mountainproject.com/route/105830332/bitchy-virgin')
# (195, 'https://www.mountainproject.com/route/105806018/hawk')
# (196, 'https://www.mountainproject.com/route/105799697/madame-grunnebaums-wulst')
# (197, 'https://www.mountainproject.com/route/106139522/son-of-bitchy-virgin')
# (198, 'https://www.mountainproject.com/route/114597806/weeping-willie-direct')
# (199, 'https://www.mountainproject.com/route/106285235/immaculate-virgin')
# (200, 'https://www.mountainproject.com/route/106089218/peregrine')
# (201, 'https://www.mountainproject.com/route/111418741/small-furry-mammals-club')
# (202, 'https://www.mountainproject.com/route/107314771/mr-ps-wurst')
# (203, 'https://www.mountainproject.com/route/106139490/columbia')
# (204, 'https://www.mountainproject.com/route/106018730/snookys-return')
# (205, 'https://www.mountainproject.com/route/106089269/bags-end')
# (206, 'https://www.mountainproject.com/route/106134098/hyjeks-horror')
# (207, 'https://www.mountainproject.com/route/105821477/friends-and-lovers')
# (208, 'https://www.mountainproject.com/route/107613265/delusions-of-grandeur')
# (209, 'https://www.mountainproject.com/route/105841807/le-teton')
# (210, 'https://www.mountainproject.com/route/105818020/beatle-brow-bulge')
# (211, 'https://www.mountainproject.com/route/106889345/tetonia')
# (212, 'https://www.mountainproject.com/route/113851850/reach-of-faith')
# (213, 'https://www.mountainproject.com/route/109094670/blueberry-wine')
# (214, 'https://www.mountainproject.com/route/115408331/smegma-garden-and-pigeon')
# (215, 'https://www.mountainproject.com/route/107889373/reds-ruin')
# (216, 'https://www.mountainproject.com/route/108406873/snowpatch')
# (217, 'https://www.mountainproject.com/route/106270916/snake')
# (218, 'https://www.mountainproject.com/route/106143697/wisecrack')
# (219, 'https://www.mountainproject.com/route/105815029/middle-earth')
# (220, 'https://www.mountainproject.com/route/105799785/v-3')
# (221, 'https://www.mountainproject.com/route/105907855/alley-oop')
# (222, 'https://www.mountainproject.com/route/106238205/cakewalk')
# (223, 'https://www.mountainproject.com/route/107037497/bombs-away-dream-baby')
# (224, 'https://www.mountainproject.com/route/105801058/thin-slabs-thin-slabs-direct')
# (225, 'https://www.mountainproject.com/route/105799190/absurdland')
# (226, 'https://www.mountainproject.com/route/113702738/sheep-thrills')
# (227, 'https://www.mountainproject.com/route/106718414/talus-of-powder')
# (228, 'https://www.mountainproject.com/route/105884378/raunchy')
# (229, 'https://www.mountainproject.com/route/106143715/wonderland')
# (230, 'https://www.mountainproject.com/route/106877274/faithful-journey')
# (231, 'https://www.mountainproject.com/route/106495360/dry-heaves')
# (232, 'https://www.mountainproject.com/route/105799187/turdland')
# (233, 'https://www.mountainproject.com/route/105847932/triangle')
# (234, 'https://www.mountainproject.com/route/105841798/sente')
# (235, 'https://www.mountainproject.com/route/106565362/beyond-the-fringe')
# (236, 'https://www.mountainproject.com/route/106146808/gory-thumb')
# (237, 'https://www.mountainproject.com/route/106146816/badfinger')
# (238, 'https://www.mountainproject.com/route/108242249/blunderbus')
# (239, 'https://www.mountainproject.com/route/105920916/commando-rave')
# (240, 'https://www.mountainproject.com/route/112217799/galactic-hitchhikers')
# (241, 'https://www.mountainproject.com/route/106146799/wild-horses')
# (242, 'https://www.mountainproject.com/route/105799095/never-never-land')
# (243, 'https://www.mountainproject.com/route/107466579/nevermore')
# (244, 'https://www.mountainproject.com/route/106189152/city-streets')
# (245, 'https://www.mountainproject.com/route/105920912/balrog')
# (246, 'https://www.mountainproject.com/route/106291093/dis-mantel')
# (247, 'https://www.mountainproject.com/route/107226291/dat-mantel')
# (248, 'https://www.mountainproject.com/route/106046438/jaccuse')
# (249, 'https://www.mountainproject.com/route/109007970/yenta')
# (250, 'https://www.mountainproject.com/route/109172875/cheap-thrills')
# (251, 'https://www.mountainproject.com/route/105799102/never-say-never')
# (252, 'https://www.mountainproject.com/route/112278272/set-my-bow-in-the-cloud')
# (253, 'https://www.mountainproject.com/route/106208236/on-any-monday')
# (254, 'https://www.mountainproject.com/route/106853208/country-roads')
# (255, 'https://www.mountainproject.com/route/107821314/bullfrog')
# (256, 'https://www.mountainproject.com/route/113705603/large-hardon-collider')
# (257, 'https://www.mountainproject.com/route/106009517/easy-verschneidung-easy-v')
# (258, 'https://www.mountainproject.com/route/106511486/andrew')
# (259, 'https://www.mountainproject.com/route/105813398/updraft')
# (260, 'https://www.mountainproject.com/route/105806552/red-pillar')
# (261, 'https://www.mountainproject.com/route/105950518/the-last-will-be-first')
# (262, 'https://www.mountainproject.com/route/105803407/moonlight')
# (263, 'https://www.mountainproject.com/route/111224033/wop-stop')
# (264, 'https://www.mountainproject.com/route/106555418/lost-and-found')
# (265, 'https://www.mountainproject.com/route/105801563/limelight')
# (266, 'https://www.mountainproject.com/route/106046446/hans-puss')
# (267, 'https://www.mountainproject.com/route/106612308/silhouette')
# (268, 'https://www.mountainproject.com/route/106734594/jims-gem')
# (269, 'https://www.mountainproject.com/route/110868757/deep-lichen')
# (270, 'https://www.mountainproject.com/route/105801065/cascading-crystal-kaleidoscope-cck')
# (271, 'https://www.mountainproject.com/route/106862975/moby-dick')
# (272, 'https://www.mountainproject.com/route/105799105/arrow')
# (273, 'https://www.mountainproject.com/route/106739395/diana')
# (274, 'https://www.mountainproject.com/route/106711001/android-moby-dick-link-up')
# (275, 'https://www.mountainproject.com/route/106565353/unholy-wick')
# (276, 'https://www.mountainproject.com/route/105801570/annie-oh')
# (277, 'https://www.mountainproject.com/route/105799085/modern-times')
# (278, 'https://www.mountainproject.com/route/105868264/three-doves')
# (279, 'https://www.mountainproject.com/route/106490427/traverse-of-the-clods')
# (280, 'https://www.mountainproject.com/route/113080646/quiver')
# (281, 'https://www.mountainproject.com/route/105811547/no-glow')
# (282, 'https://www.mountainproject.com/route/106246555/three-vultures')
# (283, 'https://www.mountainproject.com/route/106148512/cold-turkeys')
# (284, 'https://www.mountainproject.com/route/106570961/steep-hikin')
# (285, 'https://www.mountainproject.com/route/105801940/cck-direct')
# (286, 'https://www.mountainproject.com/route/109546911/hawkeye')
# (287, 'https://www.mountainproject.com/route/106089673/proctoscope')
# (288, 'https://www.mountainproject.com/route/106089682/proctor-silex')
# (289, 'https://www.mountainproject.com/route/105826771/keep-on-struttin')
# (290, 'https://www.mountainproject.com/route/106607648/amber-waves-of-pain')
# (291, 'https://www.mountainproject.com/route/106739168/step-lively')
# (292, 'https://www.mountainproject.com/route/106089261/face-to-face')
# (293, 'https://www.mountainproject.com/route/105799568/feast-of-fools')
# (294, 'https://www.mountainproject.com/route/105799041/erect-direction')
# (295, 'https://www.mountainproject.com/route/105799082/nurses-aid')
# (296, 'https://www.mountainproject.com/route/113897838/three-vultures-direct')
# (297, 'https://www.mountainproject.com/route/113639089/strolling-on-jupiter')
# (298, 'https://www.mountainproject.com/route/107771665/mans-quest-for-flight')
# (299, 'https://www.mountainproject.com/route/112426662/crack-n-up')
# (300, 'https://www.mountainproject.com/route/105877392/suppers-ready')
# (301, 'https://www.mountainproject.com/route/115446450/vanishing-point')
# (302, 'https://www.mountainproject.com/route/108002758/smilin-the-hard-way')
# (303, 'https://www.mountainproject.com/route/109555842/twilight-zone')
# (304, 'https://www.mountainproject.com/route/106792907/silly-chimney')
# (305, 'https://www.mountainproject.com/route/109076690/in-the-silly')
# (306, 'https://www.mountainproject.com/route/109526250/third-trapps-chimney')
# (307, 'https://www.mountainproject.com/route/113066452/missing-but-not-lost')
# (308, 'https://www.mountainproject.com/route/106562228/50-50')
# (309, 'https://www.mountainproject.com/route/107381972/first-trapps-chimney')
# (310, 'https://www.mountainproject.com/route/105798994/high-exposure')
# (311, 'https://www.mountainproject.com/route/105840288/ursula')
# (312, 'https://www.mountainproject.com/route/106792623/in-the-groove')
# (313, 'https://www.mountainproject.com/route/106010504/sleepwalk')
# (314, 'https://www.mountainproject.com/route/106579880/lichen-forty-winks')
# (315, 'https://www.mountainproject.com/route/109700137/cool-hand-dukes')
# (316, 'https://www.mountainproject.com/route/106731336/alpine-diversions')
# (317, 'https://www.mountainproject.com/route/110980901/lakatakissima')
# (318, 'https://www.mountainproject.com/route/105828999/groovy')
# (319, 'https://www.mountainproject.com/route/106576675/nose-drops')
# (320, 'https://www.mountainproject.com/route/106598659/insuhlation')
# (321, 'https://www.mountainproject.com/route/105799563/directissima')
# (322, 'https://www.mountainproject.com/route/106148500/obstacle-delusion')
# (323, 'https://www.mountainproject.com/route/105801433/bonnies-roof')
# (324, 'https://www.mountainproject.com/route/105803260/ants-line')
# (325, 'https://www.mountainproject.com/route/106733193/teeny-face')
# (326, 'https://www.mountainproject.com/route/105799077/directississima')
# (327, 'https://www.mountainproject.com/route/105888125/ridicullissima')
# (328, 'https://www.mountainproject.com/route/106232452/ent-line')
# (329, 'https://www.mountainproject.com/route/105841801/space-invaders')
# (330, 'https://www.mountainproject.com/route/107328856/enduro-mans-longest-hangout')
# (331, 'https://www.mountainproject.com/route/106077032/the-throne')
# (332, 'https://www.mountainproject.com/route/109610100/broken-hammer')
# (333, 'https://www.mountainproject.com/route/107866811/49')
# (334, 'https://www.mountainproject.com/route/105800339/48')
# (335, 'https://www.mountainproject.com/route/106789177/full-face-pitch-2-only')
# (336, 'https://www.mountainproject.com/route/112279369/wrath-of-the-lamb')
# (337, 'https://www.mountainproject.com/route/108063699/the-nose')
# (338, 'https://www.mountainproject.com/route/106870148/shit-creek')
# (339, 'https://www.mountainproject.com/route/106554894/ladys-lament-boldville')
# (340, 'https://www.mountainproject.com/route/105806624/bold-ville')
# (341, 'https://www.mountainproject.com/route/106754499/torture-garden')
# (342, 'https://www.mountainproject.com/route/106018758/oblique-twique')
# (343, 'https://www.mountainproject.com/route/106018762/blistered-toe')
# (344, 'https://www.mountainproject.com/route/105806583/double-crack')
# (345, 'https://www.mountainproject.com/route/105806589/airy-aria')
# (346, 'https://www.mountainproject.com/route/106148440/ivan-and-the-saum')
# (347, 'https://www.mountainproject.com/route/106148478/lisa')
# (348, 'https://www.mountainproject.com/route/106554766/fillipina')
# (349, 'https://www.mountainproject.com/route/105814941/ventre-de-boeuf')
# (350, 'https://www.mountainproject.com/route/106739130/los-tres-cabrones')
# (351, 'https://www.mountainproject.com/route/106018746/the-spring-p1')
# (352, 'https://www.mountainproject.com/route/115325123/mona')
# (353, 'https://www.mountainproject.com/route/106733159/high-jinx')
# (354, 'https://www.mountainproject.com/route/106089957/lito-and-the-swan')
# (355, 'https://www.mountainproject.com/route/106813976/lost-in-yellow')
# (356, 'https://www.mountainproject.com/route/113603406/tweak-or-freak')
# (357, 'https://www.mountainproject.com/route/107516922/vader')
# (358, 'https://www.mountainproject.com/route/108813461/manly-yes-but-i-like-it-too')
# (359, 'https://www.mountainproject.com/route/106238729/the-winter')
# (360, 'https://www.mountainproject.com/route/105798933/carbs-and-caffeine')
# (361, 'https://www.mountainproject.com/route/105888230/the-fall')
# (362, 'https://www.mountainproject.com/route/105798938/no-mans-land')
# (363, 'https://www.mountainproject.com/route/105798924/the-yellow-wall')
# (364, 'https://www.mountainproject.com/route/105898985/the-sting')
# (365, 'https://www.mountainproject.com/route/106948350/the-summer')
# (366, 'https://www.mountainproject.com/route/112426725/dissonance')
# (367, 'https://www.mountainproject.com/route/108002791/tiers-of-fear')
# (368, 'https://www.mountainproject.com/route/106076954/uphill-all-the-way-aka-the-man-who-fell-to-earth')
# (369, 'https://www.mountainproject.com/route/111291062/wasp-stop')
# (370, 'https://www.mountainproject.com/route/106389128/scary-area')
# (371, 'https://www.mountainproject.com/route/113624593/prick-the')
# (372, 'https://www.mountainproject.com/route/109528142/the-blue-stink')
# (373, 'https://www.mountainproject.com/route/111281525/sticky-gate')
# (374, 'https://www.mountainproject.com/route/111281627/raindance')
# (375, 'https://www.mountainproject.com/route/107037481/sundance')
# (376, 'https://www.mountainproject.com/route/107037493/moondance')
# (377, 'https://www.mountainproject.com/route/110360975/hooky')
# (378, 'https://www.mountainproject.com/route/107397712/sticky-gate-with-direct-finish')
# (379, 'https://www.mountainproject.com/route/106569152/tangled-up-and-blue')
# (380, 'https://www.mountainproject.com/route/105830801/wasp')
# (381, 'https://www.mountainproject.com/route/110386969/coprophagia')
# (382, 'https://www.mountainproject.com/route/105818206/simple-suff')
# (383, 'https://www.mountainproject.com/route/105799072/falled-on-account-of-strain')
# (384, 'https://www.mountainproject.com/route/106657433/last-frontier')
# (385, 'https://www.mountainproject.com/route/108252898/back-to-the-future-aka-jap')
# (386, 'https://www.mountainproject.com/route/105824824/frustration-syndrome')
# (387, 'https://www.mountainproject.com/route/106395672/bragg-hatch')
# (388, 'https://www.mountainproject.com/route/107357222/golden-showers')
# (389, 'https://www.mountainproject.com/route/106077540/the-stand')
# (390, 'https://www.mountainproject.com/route/107342001/april-showers')
# (391, 'https://www.mountainproject.com/route/106077545/comedy-in-three-acts')
# (392, 'https://www.mountainproject.com/route/108430321/climb-and-punishment')
# (393, 'https://www.mountainproject.com/route/107486305/kligfields-follies')
# (394, 'https://www.mountainproject.com/route/107797205/techno-suff')
# (395, 'https://www.mountainproject.com/route/113015330/that-thing')
# (396, 'https://www.mountainproject.com/route/114129141/drop-zone')
# (397, 'https://www.mountainproject.com/route/110849183/wet-dream')
# (398, 'https://www.mountainproject.com/route/113450673/pressure-drop')
# (399, 'https://www.mountainproject.com/route/109610469/rogers-escape-hatch')
# (400, 'https://www.mountainproject.com/route/106146834/the-lone-ranger')
# (401, 'https://www.mountainproject.com/route/109527979/four-foot-face')
# (402, 'https://www.mountainproject.com/route/105800896/casa-emilio')
# (403, 'https://www.mountainproject.com/route/109161193/pfui-teufel')
# (404, 'https://www.mountainproject.com/route/106554245/a-long-walk-for-man-a-short-climb-for-mankind')
# (405, 'https://www.mountainproject.com/route/109077172/emilietta')
# (406, 'https://www.mountainproject.com/route/108388344/crack-of-despondency')
# (407, 'https://www.mountainproject.com/route/111807940/rangers-revenge')
# (408, 'https://www.mountainproject.com/route/105972375/trigger-point')
# (409, 'https://www.mountainproject.com/route/108197328/dicks-prick')
# (410, 'https://www.mountainproject.com/route/107308180/penal-colonycircumcision-link-up')
# (411, 'https://www.mountainproject.com/route/111787942/emilio')
# (412, 'https://www.mountainproject.com/route/106395422/almost-pure-and-simple')
# (413, 'https://www.mountainproject.com/route/106551414/footloose')
# (414, 'https://www.mountainproject.com/route/106550688/fancy-free')
# (415, 'https://www.mountainproject.com/route/105825882/casablanca')
# (416, 'https://www.mountainproject.com/route/106395410/counterstrike')
# (417, 'https://www.mountainproject.com/route/106435212/arts-route')
# (418, 'https://www.mountainproject.com/route/111064796/the-devil-made-me-do-it')
# (419, 'https://www.mountainproject.com/route/106604512/casanova')
# (420, 'https://www.mountainproject.com/route/106395393/wegetables-ive-never-seen-before')
# (421, 'https://www.mountainproject.com/route/107303463/vd')
# (422, 'https://www.mountainproject.com/route/106395385/boron-destroyer')
# (423, 'https://www.mountainproject.com/route/106089227/creaky-joints-and-trigger-points')
# (424, 'https://www.mountainproject.com/route/106774183/headless-horseman')
# (425, 'https://www.mountainproject.com/route/106214631/tennish-anyone')
# (426, 'https://www.mountainproject.com/route/106598679/independent-hangover')
# (427, 'https://www.mountainproject.com/route/105799068/10000-restless-virgins')
# (428, 'https://www.mountainproject.com/route/111064746/meat-by-products')
# (429, 'https://www.mountainproject.com/route/114933479/slime-world')
# (430, 'https://www.mountainproject.com/route/111059966/future-shock')
# (431, 'https://www.mountainproject.com/route/111476310/bone-hard')
# (432, 'https://www.mountainproject.com/route/106520369/uberfall-descent')
# (433, 'https://www.mountainproject.com/route/106134047/crimson-corner')
# (434, 'https://www.mountainproject.com/route/106511488/dirty-chimney')
# (435, 'https://www.mountainproject.com/route/107204503/the-flake')
# (436, 'https://www.mountainproject.com/route/112109828/wriggles')
# (437, 'https://www.mountainproject.com/route/106866202/das-wiggles')
# (438, 'https://www.mountainproject.com/route/106099552/harvard')
# (439, 'https://www.mountainproject.com/route/109149831/yale')
# (440, 'https://www.mountainproject.com/route/110512387/the-star-route')
# (441, 'https://www.mountainproject.com/route/106133962/squiggles')
# (442, 'https://www.mountainproject.com/route/106031901/boston')
# (443, 'https://www.mountainproject.com/route/111133222/crowberry-ridge')
# (444, 'https://www.mountainproject.com/route/113805195/penn')
# (445, 'https://www.mountainproject.com/route/108445716/eyesore')
# (446, 'https://www.mountainproject.com/route/105810485/rhododendron')
# (447, 'https://www.mountainproject.com/route/105810464/laurel')
# (448, 'https://www.mountainproject.com/route/106176598/cc-route')
# (449, 'https://www.mountainproject.com/route/107282255/clover')
# (450, 'https://www.mountainproject.com/route/105799779/kens-crack')
# (451, 'https://www.mountainproject.com/route/106034638/trapped-like-a-rat')
# (452, 'https://www.mountainproject.com/route/113116195/no-pro')
# (453, 'https://www.mountainproject.com/route/106587817/fitschens-folly')
# (454, 'https://www.mountainproject.com/route/106134040/bb-route')
# (455, 'https://www.mountainproject.com/route/107081330/mitty-mouse')
# (456, 'https://www.mountainproject.com/route/106133976/walter-mitty')
# (457, 'https://www.mountainproject.com/route/106208732/junior')
# (458, 'https://www.mountainproject.com/route/106581984/charie')
# (459, 'https://www.mountainproject.com/route/107524902/dd-route')
# (460, 'https://www.mountainproject.com/route/106138061/squiggles-direct')
# (461, 'https://www.mountainproject.com/route/106138074/jacobs-ladder')
# (462, 'https://www.mountainproject.com/route/109672957/unknown-aka-ken-and-the-art-of-motorcycle-maintenance')
# (463, 'https://www.mountainproject.com/route/105855228/phoebe')
# (464, 'https://www.mountainproject.com/route/111864229/birch')
# (465, 'https://www.mountainproject.com/route/106133985/susie-a')
# (466, 'https://www.mountainproject.com/route/109055246/shitty-mitty')
# (467, 'https://www.mountainproject.com/route/106640673/hudsons-boulder-problem-aka-trashcan-overhang')
# (468, 'https://www.mountainproject.com/route/106456276/low-exposure')
# (469, 'https://www.mountainproject.com/route/112930386/freebie')

# %%
df_ratings = pd.read_csv(ratings_file)
# df_ratings.style.format(make_clickable, subset=['user_url', 'route_url'])
df_ratings.sample(3)
# Out:
#       rating                                                        route_url  \
# 5971       4  https://www.mountainproject.com/route/105803228/stirrup-trouble
# 2948       4         https://www.mountainproject.com/route/105799032/nosedive
# 6265       2    https://www.mountainproject.com/route/106034654/easy-overhang
#
#                                                           user_url
# 5971     https://www.mountainproject.com/user/107238223/tony-lopez
# 2948  https://www.mountainproject.com/user/107026497/jason-shermer
# 6265      https://www.mountainproject.com/user/106468686/tdavidock

# %% [markdown]
# # 4. Extract data about each unique climber

# %%
def extract_user_data(user_url):
    """Get info about each user.
    """
    source = urllib2.urlopen(user_url).read()
    soup = bs.BeautifulSoup(source, 'lxml')
    
    # Get user name
    name = soup.find('h2', class_='dont-shrink mb-0').text
    
    # All info under the name
    profile_list = soup.find('div', class_='col-xs-12 text-xs-center').find('div').text.split()
    profile = ' '.join(profile_list)

    return {'name':name, 'profile':profile}

# %%
def extract_all_users_data(route_ratings_file, user_data_file):
    """Take unique user urls from a the csv file route_ratings_file.
    Extract all the data for each user.
    Save it in the csv file user_data_file.
    """
    df_ratings = pd.read_csv(route_ratings_file)
    
    # Get only the unique users
    user_urls = df_ratings['user_url'].unique()
    print user_urls.shape
    user_data_list = []
    nusers = len(user_urls)
    for i in range(nusers):
        url = user_urls[i]
        print(i, url)
        data = extract_user_data(url)
        data['uid'] = i
        data['user_url'] = url
        user_data_list.append(data)
    
    df = pd.DataFrame(user_data_list)
    df.to_csv(user_data_file, index=False, encoding='utf-8')

# %%
route_ratings_file = '../data/route_ratings.csv'
user_data_file = '../data/user_data.csv'
extract_all_users_data(route_ratings_file, user_data_file)
# Out:
# (2432,)
# (0, 'https://www.mountainproject.com/user/106087077/mark-roth')
# (1, 'https://www.mountainproject.com/user/109581184/joel-ryan')
# (2, 'https://www.mountainproject.com/user/200223567/anyo-lesiuk')
# (3, 'https://www.mountainproject.com/user/107253738/dragons')
# (4, 'https://www.mountainproject.com/user/106630260/j-serpico')
# (5, 'https://www.mountainproject.com/user/110409351/ben-hoste')
# (6, 'https://www.mountainproject.com/user/109206590/john271')
# (7, 'https://www.mountainproject.com/user/112449870/david-kerkeslager')
# (8, 'https://www.mountainproject.com/user/112460885/nicole-vidal')
# (9, 'https://www.mountainproject.com/user/113522523/shionanlim')
# (10, 'https://www.mountainproject.com/user/106679659/jonathan-steitzer')
# (11, 'https://www.mountainproject.com/user/107518458/kurtz')
# (12, 'https://www.mountainproject.com/user/112423730/albi-eds')
# (13, 'https://www.mountainproject.com/user/106646308/kiff')
# (14, 'https://www.mountainproject.com/user/110729900/j-l')
# (15, 'https://www.mountainproject.com/user/200168968/raja-hamid')
# (16, 'https://www.mountainproject.com/user/109136692/villen')
# (17, 'https://www.mountainproject.com/user/108110425/jason-m-g')
# (18, 'https://www.mountainproject.com/user/108098319/paulsjourney')
# (19, 'https://www.mountainproject.com/user/106588356/ryan-r')
# (20, 'https://www.mountainproject.com/user/108324210/enoch-m')
# (21, 'https://www.mountainproject.com/user/110144057/josh-seymour')
# (22, 'https://www.mountainproject.com/user/108849186/antonio-cardona')
# (23, 'https://www.mountainproject.com/user/110253489/dan-katz')
# (24, 'https://www.mountainproject.com/user/107516828/genghis314')
# (25, 'https://www.mountainproject.com/user/108125264/ami')
# (26, 'https://www.mountainproject.com/user/108988764/gunks-jesse')
# (27, 'https://www.mountainproject.com/user/112924258/eric-christian')
# (28, 'https://www.mountainproject.com/user/111341867/b-leary')
# (29, 'https://www.mountainproject.com/user/111308179/nancyjo-p')
# (30, 'https://www.mountainproject.com/user/107830036/oren')
# (31, 'https://www.mountainproject.com/user/109451199/eric-lutz')
# (32, 'https://www.mountainproject.com/user/109897147/artie-morenz')
# (33, 'https://www.mountainproject.com/user/111952375/andres-monsalve')
# (34, 'https://www.mountainproject.com/user/107852661/j-meagher')
# (35, 'https://www.mountainproject.com/user/111948648/jdmartin86')
# (36, 'https://www.mountainproject.com/user/112521413/daniel-esposito')
# (37, 'https://www.mountainproject.com/user/109142435/brian-shaffer')
# (38, 'https://www.mountainproject.com/user/107671020/will-stat')
# (39, 'https://www.mountainproject.com/user/107902567/ralph-swansen')
# (40, 'https://www.mountainproject.com/user/106641250/ben-stanford')
# (41, 'https://www.mountainproject.com/user/106774740/derek-nabozny')
# (42, 'https://www.mountainproject.com/user/107561935/ajwm-maracek')
# (43, 'https://www.mountainproject.com/user/107068335/tom-d')
# (44, 'https://www.mountainproject.com/user/106905703/klouie')
# (45, 'https://www.mountainproject.com/user/107093945/simon-thompson')
# (46, 'https://www.mountainproject.com/user/107682885/william-h')
# (47, 'https://www.mountainproject.com/user/108195022/michael-petronio')
# (48, 'https://www.mountainproject.com/user/106913581/neil-steinert')
# (49, 'https://www.mountainproject.com/user/106556149/lostlazy')
# (50, 'https://www.mountainproject.com/user/106001645/divnamite')
# (51, 'https://www.mountainproject.com/user/107748535/dan-pizzillo')
# (52, 'https://www.mountainproject.com/user/107783937/danny-weisberg')
# (53, 'https://www.mountainproject.com/user/106062921/tim-schafstall')
# (54, 'https://www.mountainproject.com/user/106394111/lucander')
# (55, 'https://www.mountainproject.com/user/200148833/dorian-wilkerson')
# (56, 'https://www.mountainproject.com/user/111777299/aparnas')
# (57, 'https://www.mountainproject.com/user/106089213/ross-fadely')
# (58, 'https://www.mountainproject.com/user/107493811/norm-rasmussen')
# (59, 'https://www.mountainproject.com/user/107735256/nick-hamilton')
# (60, 'https://www.mountainproject.com/user/106280741/jay-harrison')
# (61, 'https://www.mountainproject.com/user/109250801/matthew-botos')
# (62, 'https://www.mountainproject.com/user/106732573/derick-l')
# (63, 'https://www.mountainproject.com/user/107379236/minquatrails')
# (64, 'https://www.mountainproject.com/user/108189638/jpietr03-pietropaolo')
# (65, 'https://www.mountainproject.com/user/107434457/brian-monetti')
# (66, 'https://www.mountainproject.com/user/109767025/alex-perfect')
# (67, 'https://www.mountainproject.com/user/109907430/davebaker')
# (68, 'https://www.mountainproject.com/user/107464151/eriks-rozners')
# (69, 'https://www.mountainproject.com/user/106715003/climbing-around')
# (70, 'https://www.mountainproject.com/user/106347425/mojomonkey')
# (71, 'https://www.mountainproject.com/user/112077859/jeff-polhemus')
# (72, 'https://www.mountainproject.com/user/108813578/ross-glinkenhouse')
# (73, 'https://www.mountainproject.com/user/106408932/sunder')
# (74, 'https://www.mountainproject.com/user/108853980/kellie-mcguire')
# (75, 'https://www.mountainproject.com/user/108857846/mark-dickey')
# (76, 'https://www.mountainproject.com/user/107789096/adam-marcus')
# (77, 'https://www.mountainproject.com/user/111349766/negro-montoya')
# (78, 'https://www.mountainproject.com/user/107400911/jesse-newton')
# (79, 'https://www.mountainproject.com/user/111841207/mandy-potemkin')
# (80, 'https://www.mountainproject.com/user/107559594/chris-mason')
# (81, 'https://www.mountainproject.com/user/107532062/bill-l')
# (82, 'https://www.mountainproject.com/user/106325770/chris-vultaggio')
# (83, 'https://www.mountainproject.com/user/106299993/aghetie')
# (84, 'https://www.mountainproject.com/user/107421393/raze-taylor')
# (85, 'https://www.mountainproject.com/user/107324126/chris-bartram')
# (86, 'https://www.mountainproject.com/user/106477370/matt-peres')
# (87, 'https://www.mountainproject.com/user/106869562/jbaker-baker')
# (88, 'https://www.mountainproject.com/user/107056240/carlenetak')
# (89, 'https://www.mountainproject.com/user/106737343/hana')
# (90, 'https://www.mountainproject.com/user/106407009/richard-hunter')
# (91, 'https://www.mountainproject.com/user/106180994/glenn61')
# (92, 'https://www.mountainproject.com/user/108187975/jon-booth')
# (93, 'https://www.mountainproject.com/user/106617556/dara')
# (94, 'https://www.mountainproject.com/user/106666369/mark-straub')
# (95, 'https://www.mountainproject.com/user/107764627/dan-felix')
# (96, 'https://www.mountainproject.com/user/107239710/extrablue-lain')
# (97, 'https://www.mountainproject.com/user/110735180/rmsu')
# (98, 'https://www.mountainproject.com/user/108179333/beach')
# (99, 'https://www.mountainproject.com/user/108367150/jon-po')
# (100, 'https://www.mountainproject.com/user/107587392/john-l')
# (101, 'https://www.mountainproject.com/user/110628071/dev-more')
# (102, 'https://www.mountainproject.com/user/109586477/ryan-m-moore')
# (103, 'https://www.mountainproject.com/user/111888705/andre-malan')
# (104, 'https://www.mountainproject.com/user/112118431/daniel-storms')
# (105, 'https://www.mountainproject.com/user/107876007/kurt-g')
# (106, 'https://www.mountainproject.com/user/110631955/crestaino-restaino')
# (107, 'https://www.mountainproject.com/user/200062003/jean-provost')
# (108, 'https://www.mountainproject.com/user/200020794/andrea-fairservice')
# (109, 'https://www.mountainproject.com/user/109692317/daniel-kaye')
# (110, 'https://www.mountainproject.com/user/107691094/pawel-sokolowski')
# (111, 'https://www.mountainproject.com/user/200075502/tad-mask')
# (112, 'https://www.mountainproject.com/user/111467330/theodore-gregg')
# (113, 'https://www.mountainproject.com/user/112314245/daniel-crowe')
# (114, 'https://www.mountainproject.com/user/106440310/chris-mak')
# (115, 'https://www.mountainproject.com/user/112116113/gavin-alcott')
# (116, 'https://www.mountainproject.com/user/108793472/mmacelhi')
# (117, 'https://www.mountainproject.com/user/200286398/jesse-badash')
# (118, 'https://www.mountainproject.com/user/200309663/katie-r')
# (119, 'https://www.mountainproject.com/user/200357691/joey-caffrey')
# (120, 'https://www.mountainproject.com/user/108106981/cidamon-gd')
# (121, 'https://www.mountainproject.com/user/107400819/sketcher')
# (122, 'https://www.mountainproject.com/user/106205646/gmburns')
# (123, 'https://www.mountainproject.com/user/106567319/mike-mclean')
# (124, 'https://www.mountainproject.com/user/106762873/eric-albers')
# (125, 'https://www.mountainproject.com/user/13658/rob-bauer')
# (126, 'https://www.mountainproject.com/user/106607660/johnwesely')
# (127, 'https://www.mountainproject.com/user/106822110/kevin-heckeler')
# (128, 'https://www.mountainproject.com/user/106797746/valerie-ab')
# (129, 'https://www.mountainproject.com/user/106863637/adkeditor-brown')
# (130, 'https://www.mountainproject.com/user/106456515/zach-s')
# (131, 'https://www.mountainproject.com/user/107872722/stephen-bittner')
# (132, 'https://www.mountainproject.com/user/108674850/ccas')
# (133, 'https://www.mountainproject.com/user/109405478/patrick-killian')
# (134, 'https://www.mountainproject.com/user/106993942/luc-514')
# (135, 'https://www.mountainproject.com/user/108259746/jim-thayer')
# (136, 'https://www.mountainproject.com/user/105890911/greg-davis')
# (137, 'https://www.mountainproject.com/user/110036457/griff-keating')
# (138, 'https://www.mountainproject.com/user/108037217/toni-stey')
# (139, 'https://www.mountainproject.com/user/112134885/live-perched')
# (140, 'https://www.mountainproject.com/user/106405973/jon-clark')
# (141, 'https://www.mountainproject.com/user/200069906/jenni-w')
# (142, 'https://www.mountainproject.com/user/112546186/david-stephenson')
# (143, 'https://www.mountainproject.com/user/108590756/cris-dizon')
# (144, 'https://www.mountainproject.com/user/106846955/melanie-lebel')
# (145, 'https://www.mountainproject.com/user/107643882/jmkeupp')
# (146, 'https://www.mountainproject.com/user/105812807/christopher-adams')
# (147, 'https://www.mountainproject.com/user/107499312/lantz')
# (148, 'https://www.mountainproject.com/user/107536174/medic741')
# (149, 'https://www.mountainproject.com/user/200032696/adam-gong')
# (150, 'https://www.mountainproject.com/user/200287389/samir-chopra')
# (151, 'https://www.mountainproject.com/user/110336734/ethan-george')
# (152, 'https://www.mountainproject.com/user/111724726/seth-d')
# (153, 'https://www.mountainproject.com/user/107916193/rutherc-xyz')
# (154, 'https://www.mountainproject.com/user/111952379/roberto-noensie')
# (155, 'https://www.mountainproject.com/user/108394904/cody-robinson')
# (156, 'https://www.mountainproject.com/user/109597474/hayley-jeanne')
# (157, 'https://www.mountainproject.com/user/200134718/georgia-burr')
# (158, 'https://www.mountainproject.com/user/111829790/cvanpak')
# (159, 'https://www.mountainproject.com/user/110190703/armand-koher')
# (160, 'https://www.mountainproject.com/user/200132139/ted-wilson')
# (161, 'https://www.mountainproject.com/user/111811598/ben-juneau')
# (162, 'https://www.mountainproject.com/user/110165451/mike-hazard')
# (163, 'https://www.mountainproject.com/user/109037301/jon-golle')
# (164, 'https://www.mountainproject.com/user/108362531/airingout')
# (165, 'https://www.mountainproject.com/user/106285259/lori-debardelaben')
# (166, 'https://www.mountainproject.com/user/108222065/k-swissto')
# (167, 'https://www.mountainproject.com/user/108680900/ryan-west')
# (168, 'https://www.mountainproject.com/user/109079758/sheindl-heindl')
# (169, 'https://www.mountainproject.com/user/106238291/ben-j')
# (170, 'https://www.mountainproject.com/user/107217526/adam-fernandez')
# (171, 'https://www.mountainproject.com/user/107542557/salim-r')
# (172, 'https://www.mountainproject.com/user/107483048/thatcher-clay')
# (173, 'https://www.mountainproject.com/user/106766740/felix-duvallet')
# (174, 'https://www.mountainproject.com/user/10185/guy-h')
# (175, 'https://www.mountainproject.com/user/10202/paul-crowder')
# (176, 'https://www.mountainproject.com/user/107525760/anfarwal-vr')
# (177, 'https://www.mountainproject.com/user/107228100/galen-rahmlow')
# (178, 'https://www.mountainproject.com/user/106999733/tgv-james')
# (179, 'https://www.mountainproject.com/user/105829522/jeff-welch')
# (180, 'https://www.mountainproject.com/user/105829681/genghis')
# (181, 'https://www.mountainproject.com/user/106726952/john-halupowski')
# (182, 'https://www.mountainproject.com/user/105873502/bob-graham')
# (183, 'https://www.mountainproject.com/user/107592563/lizzy-d')
# (184, 'https://www.mountainproject.com/user/107272204/dean-samaha')
# (185, 'https://www.mountainproject.com/user/107619437/eric-holmberg')
# (186, 'https://www.mountainproject.com/user/107174265/farkastime')
# (187, 'https://www.mountainproject.com/user/107222279/michael-smith')
# (188, 'https://www.mountainproject.com/user/106785304/chalu-kim')
# (189, 'https://www.mountainproject.com/user/107523564/mario-cabodi')
# (190, 'https://www.mountainproject.com/user/107618553/steve-moulding')
# (191, 'https://www.mountainproject.com/user/105883574/ktb')
# (192, 'https://www.mountainproject.com/user/105884346/big-perm')
# (193, 'https://www.mountainproject.com/user/106381547/vince-schaefer')
# (194, 'https://www.mountainproject.com/user/107515236/luke-w-brigham')
# (195, 'https://www.mountainproject.com/user/107107763/ted-sumers')
# (196, 'https://www.mountainproject.com/user/105927660/gavin-boyles')
# (197, 'https://www.mountainproject.com/user/106344939/vanishing-spy')
# (198, 'https://www.mountainproject.com/user/107699621/brendan-kober')
# (199, 'https://www.mountainproject.com/user/105798761/alex-kowalcyk')
# (200, 'https://www.mountainproject.com/user/107635248/matt-caldwell')
# (201, 'https://www.mountainproject.com/user/107273411/rogerbenton')
# (202, 'https://www.mountainproject.com/user/12985/aaron-costello')
# (203, 'https://www.mountainproject.com/user/107730254/ryan-nelling')
# (204, 'https://www.mountainproject.com/user/107383190/kevin-riddell')
# (205, 'https://www.mountainproject.com/user/105988971/john-lloyd')
# (206, 'https://www.mountainproject.com/user/106932935/zach-pickard')
# (207, 'https://www.mountainproject.com/user/105846944/bj-sbarra')
# (208, 'https://www.mountainproject.com/user/106246445/will-starks')
# (209, 'https://www.mountainproject.com/user/107068306/trad8')
# (210, 'https://www.mountainproject.com/user/106571266/ericcr')
# (211, 'https://www.mountainproject.com/user/105859992/tom-selleck')
# (212, 'https://www.mountainproject.com/user/106945872/sarah-meiser')
# (213, 'https://www.mountainproject.com/user/107548455/benjaminadk')
# (214, 'https://www.mountainproject.com/user/106071787/david-wilkerson')
# (215, 'https://www.mountainproject.com/user/106098470/chuck-parks')
# (216, 'https://www.mountainproject.com/user/14568/andy-laakmann')
# (217, 'https://www.mountainproject.com/user/106898020/maurice-chaunders')
# (218, 'https://www.mountainproject.com/user/107323239/christine-spang')
# (219, 'https://www.mountainproject.com/user/107786688/simon-l')
# (220, 'https://www.mountainproject.com/user/107792493/miguelc')
# (221, 'https://www.mountainproject.com/user/105811146/mobes')
# (222, 'https://www.mountainproject.com/user/105837907/c-runyan')
# (223, 'https://www.mountainproject.com/user/106108233/michael-g')
# (224, 'https://www.mountainproject.com/user/105790750/dennis')
# (225, 'https://www.mountainproject.com/user/106197143')
# (226, 'https://www.mountainproject.com/user/106398812/trevor-shearen')
# (227, 'https://www.mountainproject.com/user/14537/slim')
# (228, 'https://www.mountainproject.com/user/105898385/chris-duca')
# (229, 'https://www.mountainproject.com/user/105892598/paulmadry')
# (230, 'https://www.mountainproject.com/user/106430658/jason-antin')
# (231, 'https://www.mountainproject.com/user/106358364/tim-waystrong')
# (232, 'https://www.mountainproject.com/user/106306579/matthewwallace')
# (233, 'https://www.mountainproject.com/user/106474214/louis-tricarick')
# (234, 'https://www.mountainproject.com/user/106476214/james-ging')
# (235, 'https://www.mountainproject.com/user/106447057/tilden-daniels')
# (236, 'https://www.mountainproject.com/user/105842979/dagmar')
# (237, 'https://www.mountainproject.com/user/106121271/smithygreg')
# (238, 'https://www.mountainproject.com/user/105808487/dan-60d5h411')
# (239, 'https://www.mountainproject.com/user/106569992/shawn-adams')
# (240, 'https://www.mountainproject.com/user/105945019/nhclimber')
# (241, 'https://www.mountainproject.com/user/106263368/doligo')
# (242, 'https://www.mountainproject.com/user/105889415/losbill')
# (243, 'https://www.mountainproject.com/user/106591608/christopher-beaudoin')
# (244, 'https://www.mountainproject.com/user/106659317/vfv')
# (245, 'https://www.mountainproject.com/user/10610/jay-knower')
# (246, 'https://www.mountainproject.com/user/106011891/ross-purnell')
# (247, 'https://www.mountainproject.com/user/106687445/peterw-whitmore')
# (248, 'https://www.mountainproject.com/user/106749092/brian-rosenfeld')
# (249, 'https://www.mountainproject.com/user/106619581/greg-sudlow')
# (250, 'https://www.mountainproject.com/user/106751248/rcongo')
# (251, 'https://www.mountainproject.com/user/106588732/lee-h')
# (252, 'https://www.mountainproject.com/user/106715896/christina-callaghan')
# (253, 'https://www.mountainproject.com/user/106773591/jonathan-ward')
# (254, 'https://www.mountainproject.com/user/11156/tradiban')
# (255, 'https://www.mountainproject.com/user/106802916/anton-tokranov')
# (256, 'https://www.mountainproject.com/user/106113062/ben-c')
# (257, 'https://www.mountainproject.com/user/11690/rui-ferreira')
# (258, 'https://www.mountainproject.com/user/106680875/david-ford')
# (259, 'https://www.mountainproject.com/user/106844475/nate-mckenzie')
# (260, 'https://www.mountainproject.com/user/106895019/tim-wolsonovich')
# (261, 'https://www.mountainproject.com/user/106864388/jamboni')
# (262, 'https://www.mountainproject.com/user/106744775/patrickgensel')
# (263, 'https://www.mountainproject.com/user/106933730/worth-russell')
# (264, 'https://www.mountainproject.com/user/106968180/aleya')
# (265, 'https://www.mountainproject.com/user/106887229/mike-walley')
# (266, 'https://www.mountainproject.com/user/107028335/mattoc')
# (267, 'https://www.mountainproject.com/user/106943926/chris-peterson')
# (268, 'https://www.mountainproject.com/user/106971070/giuseppe-cavallo')
# (269, 'https://www.mountainproject.com/user/106907802/nick84')
# (270, 'https://www.mountainproject.com/user/105906559/lee-hansche')
# (271, 'https://www.mountainproject.com/user/106590583/liam')
# (272, 'https://www.mountainproject.com/user/107232016/andy-weinmann')
# (273, 'https://www.mountainproject.com/user/106963929/joe-lobel')
# (274, 'https://www.mountainproject.com/user/106874511/pdubz')
# (275, 'https://www.mountainproject.com/user/106755817/william-bridges')
# (276, 'https://www.mountainproject.com/user/106953954/brianrh')
# (277, 'https://www.mountainproject.com/user/107436921/kevin-w-burns')
# (278, 'https://www.mountainproject.com/user/107262260/nicky-delay')
# (279, 'https://www.mountainproject.com/user/106054402/eric8')
# (280, 'https://www.mountainproject.com/user/107723931/awilk-wilk')
# (281, 'https://www.mountainproject.com/user/105891309/rocknice2')
# (282, 'https://www.mountainproject.com/user/107644182/nik-orlando')
# (283, 'https://www.mountainproject.com/user/106095805/carl-a')
# (284, 'https://www.mountainproject.com/user/107953182/southey')
# (285, 'https://www.mountainproject.com/user/108096611/chris-pipas')
# (286, 'https://www.mountainproject.com/user/107278005/steven-frankel')
# (287, 'https://www.mountainproject.com/user/108139891/dan-castillo')
# (288, 'https://www.mountainproject.com/user/107629487/gtluke')
# (289, 'https://www.mountainproject.com/user/106758060/cj-whitehill')
# (290, 'https://www.mountainproject.com/user/106928886/brendan-blanchard')
# (291, 'https://www.mountainproject.com/user/108031241/anthony-chiaravallo')
# (292, 'https://www.mountainproject.com/user/107142289/rob-d')
# (293, 'https://www.mountainproject.com/user/108169776/doug-robinson')
# (294, 'https://www.mountainproject.com/user/108205352/jem')
# (295, 'https://www.mountainproject.com/user/107089682')
# (296, 'https://www.mountainproject.com/user/107125052/ben-brotelho')
# (297, 'https://www.mountainproject.com/user/106097553/benjamin-chapman')
# (298, 'https://www.mountainproject.com/user/107842362/ajmags263-mags')
# (299, 'https://www.mountainproject.com/user/106411326/kurt-arend')
# (300, 'https://www.mountainproject.com/user/106720416/steve-thomas')
# (301, 'https://www.mountainproject.com/user/107790918/fedor')
# (302, 'https://www.mountainproject.com/user/107792163/kristan-markey')
# (303, 'https://www.mountainproject.com/user/108307042/mike-marmar')
# (304, 'https://www.mountainproject.com/user/106529846/keith-meister')
# (305, 'https://www.mountainproject.com/user/106360234/cjdrover')
# (306, 'https://www.mountainproject.com/user/107226876/john-gassel')
# (307, 'https://www.mountainproject.com/user/108028939/manuel-spoerri')
# (308, 'https://www.mountainproject.com/user/108200561/zeb-c')
# (309, 'https://www.mountainproject.com/user/108391173/daniel-israel')
# (310, 'https://www.mountainproject.com/user/107620691/parick-jacques')
# (311, 'https://www.mountainproject.com/user/107553094/m-lane')
# (312, 'https://www.mountainproject.com/user/108401191/mike-df')
# (313, 'https://www.mountainproject.com/user/107588981/hj')
# (314, 'https://www.mountainproject.com/user/108156518/doug-kensicki')
# (315, 'https://www.mountainproject.com/user/107645068/joe-hopfield')
# (316, 'https://www.mountainproject.com/user/108523279/yuchen-f')
# (317, 'https://www.mountainproject.com/user/108363423/jackson-vermeulen')
# (318, 'https://www.mountainproject.com/user/108111761/stephchow')
# (319, 'https://www.mountainproject.com/user/106736701/seth-derr')
# (320, 'https://www.mountainproject.com/user/108173104/runwilburrun')
# (321, 'https://www.mountainproject.com/user/108843325/juan-vargas')
# (322, 'https://www.mountainproject.com/user/107713340/anthony-bracero')
# (323, 'https://www.mountainproject.com/user/106507389/sam-daley')
# (324, 'https://www.mountainproject.com/user/107914961/will-cohen')
# (325, 'https://www.mountainproject.com/user/108401124/nick-alunni')
# (326, 'https://www.mountainproject.com/user/108985245/dan-africk')
# (327, 'https://www.mountainproject.com/user/107614408/sal-trupia')
# (328, 'https://www.mountainproject.com/user/107100666/marty-theriault')
# (329, 'https://www.mountainproject.com/user/109359027/andrew-caldwell')
# (330, 'https://www.mountainproject.com/user/106273389/monkeyvanya')
# (331, 'https://www.mountainproject.com/user/108581360/john-tinoco')
# (332, 'https://www.mountainproject.com/user/107833965/william-mantani')
# (333, 'https://www.mountainproject.com/user/108529353/daniel-affsprung')
# (334, 'https://www.mountainproject.com/user/107544688/fan-zhang')
# (335, 'https://www.mountainproject.com/user/109156548/saint18z')
# (336, 'https://www.mountainproject.com/user/107928271/mike-kim')
# (337, 'https://www.mountainproject.com/user/109498955/emilyweninger')
# (338, 'https://www.mountainproject.com/user/108287262/kristie-miles')
# (339, 'https://www.mountainproject.com/user/107492957/derek-jf')
# (340, 'https://www.mountainproject.com/user/108972429/rajko-radovanovic')
# (341, 'https://www.mountainproject.com/user/109646398/jhenry')
# (342, 'https://www.mountainproject.com/user/106712274/j-wright')
# (343, 'https://www.mountainproject.com/user/109693572/matt-dowling-1')
# (344, 'https://www.mountainproject.com/user/107194267/marnix')
# (345, 'https://www.mountainproject.com/user/109018466/bob-johnson')
# (346, 'https://www.mountainproject.com/user/107237750/tom303')
# (347, 'https://www.mountainproject.com/user/106178530/bradley-white')
# (348, 'https://www.mountainproject.com/user/107746838/locke')
# (349, 'https://www.mountainproject.com/user/106235451/michael-goodhue')
# (350, 'https://www.mountainproject.com/user/107660333/mickey-hardt')
# (351, 'https://www.mountainproject.com/user/110359430/jesse-pena')
# (352, 'https://www.mountainproject.com/user/109554938/vince-buffalini')
# (353, 'https://www.mountainproject.com/user/109272253/m-russi')
# (354, 'https://www.mountainproject.com/user/108138324/mark-p')
# (355, 'https://www.mountainproject.com/user/110060076/alejandra-garces-pozo')
# (356, 'https://www.mountainproject.com/user/108228481/bill-west')
# (357, 'https://www.mountainproject.com/user/108267478/dawn-jacob')
# (358, 'https://www.mountainproject.com/user/108159370/elan-trybuch')
# (359, 'https://www.mountainproject.com/user/106246427/toni')
# (360, 'https://www.mountainproject.com/user/110536657/lisa-gizzarelli')
# (361, 'https://www.mountainproject.com/user/108008683/colin-garceau')
# (362, 'https://www.mountainproject.com/user/108157281/jincillo')
# (363, 'https://www.mountainproject.com/user/109280064/matthew-williams')
# (364, 'https://www.mountainproject.com/user/107980713/dlent-lent')
# (365, 'https://www.mountainproject.com/user/110877362/yo-yo')
# (366, 'https://www.mountainproject.com/user/106398706/sardocius')
# (367, 'https://www.mountainproject.com/user/108321835/sam-fox')
# (368, 'https://www.mountainproject.com/user/111126783/city-dweller')
# (369, 'https://www.mountainproject.com/user/110538349/liz-reiman')
# (370, 'https://www.mountainproject.com/user/110148121/systematic')
# (371, 'https://www.mountainproject.com/user/109688349/ajg519')
# (372, 'https://www.mountainproject.com/user/108052600/liz-han')
# (373, 'https://www.mountainproject.com/user/108085357/tyler-kempney')
# (374, 'https://www.mountainproject.com/user/109620395/maureen-petterson')
# (375, 'https://www.mountainproject.com/user/109711410/billy-simek')
# (376, 'https://www.mountainproject.com/user/107755397/ed-wade')
# (377, 'https://www.mountainproject.com/user/109411206/cameron-collins')
# (378, 'https://www.mountainproject.com/user/109634018/richard-beck')
# (379, 'https://www.mountainproject.com/user/111626699/alessandro-pruscino')
# (380, 'https://www.mountainproject.com/user/111627067/jilliancai')
# (381, 'https://www.mountainproject.com/user/110579983/brian-zilian')
# (382, 'https://www.mountainproject.com/user/111674806/merrick-schaefer')
# (383, 'https://www.mountainproject.com/user/108976941/mel-d')
# (384, 'https://www.mountainproject.com/user/111448414/hugh-zimmerbaum')
# (385, 'https://www.mountainproject.com/user/109659244/brian-zielinski')
# (386, 'https://www.mountainproject.com/user/110936779/hank-martin')
# (387, 'https://www.mountainproject.com/user/10520/brad-schildt')
# (388, 'https://www.mountainproject.com/user/109187861/eric-newman')
# (389, 'https://www.mountainproject.com/user/109280499/john-walk')
# (390, 'https://www.mountainproject.com/user/111898188/brunoluna')
# (391, 'https://www.mountainproject.com/user/108540048/joevaglio')
# (392, 'https://www.mountainproject.com/user/107377680/nate-vince')
# (393, 'https://www.mountainproject.com/user/111921579/jessadaniel')
# (394, 'https://www.mountainproject.com/user/107517124/donald-hart')
# (395, 'https://www.mountainproject.com/user/108275373/petzl-logic')
# (396, 'https://www.mountainproject.com/user/111682044/imran-anwar')
# (397, 'https://www.mountainproject.com/user/107545559/joshwood')
# (398, 'https://www.mountainproject.com/user/108178915/brian-m')
# (399, 'https://www.mountainproject.com/user/111891320/theeinjem')
# (400, 'https://www.mountainproject.com/user/111884209/ro-zuniga')
# (401, 'https://www.mountainproject.com/user/112037097/david-greenhouse-1')
# (402, 'https://www.mountainproject.com/user/111161794/justin-cina')
# (403, 'https://www.mountainproject.com/user/112050112/sara-paradis')
# (404, 'https://www.mountainproject.com/user/108014034/jon-frisby')
# (405, 'https://www.mountainproject.com/user/107494185/tdoyle')
# (406, 'https://www.mountainproject.com/user/109483250/justin-irving')
# (407, 'https://www.mountainproject.com/user/108323817/andrew-st-cyr')
# (408, 'https://www.mountainproject.com/user/111992163/m-maup')
# (409, 'https://www.mountainproject.com/user/109144070/gilashot')
# (410, 'https://www.mountainproject.com/user/109990981/brett-bergeron')
# (411, 'https://www.mountainproject.com/user/112124959/tersh')
# (412, 'https://www.mountainproject.com/user/111500558/bensuh')
# (413, 'https://www.mountainproject.com/user/108478944/yura-porotnikov')
# (414, 'https://www.mountainproject.com/user/12084/scott-gilliam')
# (415, 'https://www.mountainproject.com/user/110385197/chad-blanchard')
# (416, 'https://www.mountainproject.com/user/111574222/pat-thornton')
# (417, 'https://www.mountainproject.com/user/105801390/brian-p')
# (418, 'https://www.mountainproject.com/user/108495957/matt-carroll')
# (419, 'https://www.mountainproject.com/user/109293842/brendan-cathcart')
# (420, 'https://www.mountainproject.com/user/106980350/dylan-weldin')
# (421, 'https://www.mountainproject.com/user/110735872/eva-dixon')
# (422, 'https://www.mountainproject.com/user/112341216/tom-wainwright')
# (423, 'https://www.mountainproject.com/user/112002225/erin-nelson')
# (424, 'https://www.mountainproject.com/user/107932282/yotsuba')
# (425, 'https://www.mountainproject.com/user/106578430/cron')
# (426, 'https://www.mountainproject.com/user/108406663/foster-conklin')
# (427, 'https://www.mountainproject.com/user/110306482/naj1036')
# (428, 'https://www.mountainproject.com/user/110494556/chris-w')
# (429, 'https://www.mountainproject.com/user/112856585/matt-tizol')
# (430, 'https://www.mountainproject.com/user/112128138/nick-waz')
# (431, 'https://www.mountainproject.com/user/112440176/katherine-delia')
# (432, 'https://www.mountainproject.com/user/112091216/travis-james')
# (433, 'https://www.mountainproject.com/user/108742211/jeff-oslik')
# (434, 'https://www.mountainproject.com/user/111857489/maria-bridge')
# (435, 'https://www.mountainproject.com/user/112463509/tyler-hutchinson')
# (436, 'https://www.mountainproject.com/user/110259494/adeadhead')
# (437, 'https://www.mountainproject.com/user/111256939/roger-mitchell')
# (438, 'https://www.mountainproject.com/user/108056339/jwenstrup')
# (439, 'https://www.mountainproject.com/user/111062291/alex-wyvill')
# (440, 'https://www.mountainproject.com/user/113433883/samuel-benton')
# (441, 'https://www.mountainproject.com/user/111146152/stephen-schilling')
# (442, 'https://www.mountainproject.com/user/110937405/will-l')
# (443, 'https://www.mountainproject.com/user/200060331/nick-arthur')
# (444, 'https://www.mountainproject.com/user/108155086/guillaume-labranche')
# (445, 'https://www.mountainproject.com/user/107094471/mike-herholz')
# (446, 'https://www.mountainproject.com/user/112140841/eric-magnuson')
# (447, 'https://www.mountainproject.com/user/6123988/kyle-centrella')
# (448, 'https://www.mountainproject.com/user/200150347/damon-liu')
# (449, 'https://www.mountainproject.com/user/112134112/chris-blatchley')
# (450, 'https://www.mountainproject.com/user/111565043/dillon-manzanares')
# (451, 'https://www.mountainproject.com/user/112406611/jesse-rathod')
# (452, 'https://www.mountainproject.com/user/109092361/jud-wellington')
# (453, 'https://www.mountainproject.com/user/110816178/melinda-ching')
# (454, 'https://www.mountainproject.com/user/200053864/maya-l')
# (455, 'https://www.mountainproject.com/user/110524225/eugenel-espiritu')
# (456, 'https://www.mountainproject.com/user/200174103/magdalena-pnck')
# (457, 'https://www.mountainproject.com/user/112189270/bennett-boyer')
# (458, 'https://www.mountainproject.com/user/200141580/cloudy-mane')
# (459, 'https://www.mountainproject.com/user/106494505/gerry-carter')
# (460, 'https://www.mountainproject.com/user/200074424/evan-glessner')
# (461, 'https://www.mountainproject.com/user/200054289/david-arredondo')
# (462, 'https://www.mountainproject.com/user/200191047/damis-yancopoulos')
# (463, 'https://www.mountainproject.com/user/200158263/nickolis-irby')
# (464, 'https://www.mountainproject.com/user/108103821/tj-kieper')
# (465, 'https://www.mountainproject.com/user/200059743/derek-michael')
# (466, 'https://www.mountainproject.com/user/108320835/drrockso')
# (467, 'https://www.mountainproject.com/user/110060237/sherie-lou')
# (468, 'https://www.mountainproject.com/user/111546553/carleyt')
# (469, 'https://www.mountainproject.com/user/112512800/brian-wetzel')
# (470, 'https://www.mountainproject.com/user/200188307/victor-lopes')
# (471, 'https://www.mountainproject.com/user/200253316/ruslan-khasbulatov')
# (472, 'https://www.mountainproject.com/user/108375637/jason-bernz')
# (473, 'https://www.mountainproject.com/user/200267314/dr-ake')
# (474, 'https://www.mountainproject.com/user/111460596/drewrk')
# (475, 'https://www.mountainproject.com/user/200187164/wolf-l')
# (476, 'https://www.mountainproject.com/user/200173156/rue-kennington')
# (477, 'https://www.mountainproject.com/user/112086258/austin-hill')
# (478, 'https://www.mountainproject.com/user/106209804/scott-ghiz')
# (479, 'https://www.mountainproject.com/user/109488917/katie-hughes')
# (480, 'https://www.mountainproject.com/user/112111219/cwin')
# (481, 'https://www.mountainproject.com/user/110162234/gabe-d-castillo')
# (482, 'https://www.mountainproject.com/user/200281875/b-randon')
# (483, 'https://www.mountainproject.com/user/108270652/daniel-dunn')
# (484, 'https://www.mountainproject.com/user/110330190/michelle-ho')
# (485, 'https://www.mountainproject.com/user/106103271/bdalhaus')
# (486, 'https://www.mountainproject.com/user/111344408/dylan-levar')
# (487, 'https://www.mountainproject.com/user/111783002/a-wells')
# (488, 'https://www.mountainproject.com/user/109542989/vadim-mikheev')
# (489, 'https://www.mountainproject.com/user/200409293/vinny-casey')
# (490, 'https://www.mountainproject.com/user/200067404/max-zielinski')
# (491, 'https://www.mountainproject.com/user/200062780/aare-puussaar')
# (492, 'https://www.mountainproject.com/user/107551540/zyvandus')
# (493, 'https://www.mountainproject.com/user/107552617/b-callahan')
# (494, 'https://www.mountainproject.com/user/10909/charlesr')
# (495, 'https://www.mountainproject.com/user/106125724/ian-wauchope')
# (496, 'https://www.mountainproject.com/user/107519230/adam-faller')
# (497, 'https://www.mountainproject.com/user/106030894/brian-aitken')
# (498, 'https://www.mountainproject.com/user/107607088/danielle-nelson')
# (499, 'https://www.mountainproject.com/user/107664805/nicholas-kinloch')
# (500, 'https://www.mountainproject.com/user/105832216/buckeeb-hart')
# (501, 'https://www.mountainproject.com/user/105922412/nick-weinstock')
# (502, 'https://www.mountainproject.com/user/107678965/marlonk')
# (503, 'https://www.mountainproject.com/user/106928959/craig-mealmaker')
# (504, 'https://www.mountainproject.com/user/106915263/jmstreeto')
# (505, 'https://www.mountainproject.com/user/105904878/jeff-mekolites')
# (506, 'https://www.mountainproject.com/user/107032446/emmett-lyman')
# (507, 'https://www.mountainproject.com/user/106596992/arch-richardson')
# (508, 'https://www.mountainproject.com/user/107362139/lou-c')
# (509, 'https://www.mountainproject.com/user/10996/jake-wyatt')
# (510, 'https://www.mountainproject.com/user/107771322/kevin-wright')
# (511, 'https://www.mountainproject.com/user/105943577/ladd')
# (512, 'https://www.mountainproject.com/user/13227/j-w')
# (513, 'https://www.mountainproject.com/user/105886712/saxfiend')
# (514, 'https://www.mountainproject.com/user/107438587/john-t-young')
# (515, 'https://www.mountainproject.com/user/105885105/percious')
# (516, 'https://www.mountainproject.com/user/11278/wayne-crill')
# (517, 'https://www.mountainproject.com/user/105797324/1eric-rhicard')
# (518, 'https://www.mountainproject.com/user/106117267/mike-caruso')
# (519, 'https://www.mountainproject.com/user/106041457/malyciara')
# (520, 'https://www.mountainproject.com/user/106297607/john-ely')
# (521, 'https://www.mountainproject.com/user/107119375/doublediamond100')
# (522, 'https://www.mountainproject.com/user/106207412/monk')
# (523, 'https://www.mountainproject.com/user/105899248/spiro-spiro')
# (524, 'https://www.mountainproject.com/user/106958111/jenly')
# (525, 'https://www.mountainproject.com/user/106230078/dan-smith')
# (526, 'https://www.mountainproject.com/user/105930639/sean-cobourn')
# (527, 'https://www.mountainproject.com/user/105804842/michael-john-gray')
# (528, 'https://www.mountainproject.com/user/105801876/jim-obrien')
# (529, 'https://www.mountainproject.com/user/106493776/zivigliano')
# (530, 'https://www.mountainproject.com/user/105851541/kalil-oldham')
# (531, 'https://www.mountainproject.com/user/106290147/anthony-baraff')
# (532, 'https://www.mountainproject.com/user/106132247/bgraham')
# (533, 'https://www.mountainproject.com/user/106666668/karma-smith')
# (534, 'https://www.mountainproject.com/user/106423391/dan-flynn')
# (535, 'https://www.mountainproject.com/user/106588964/matt-meuse')
# (536, 'https://www.mountainproject.com/user/10752/jeff-st-pierre')
# (537, 'https://www.mountainproject.com/user/106155889/michelle-marshall')
# (538, 'https://www.mountainproject.com/user/106301735/skendrick')
# (539, 'https://www.mountainproject.com/user/106755863/christopher-james-calo')
# (540, 'https://www.mountainproject.com/user/106680929/adh')
# (541, 'https://www.mountainproject.com/user/106904560/mike-royer')
# (542, 'https://www.mountainproject.com/user/106876834/sarah-schmidt')
# (543, 'https://www.mountainproject.com/user/106935500/francois-brunelle')
# (544, 'https://www.mountainproject.com/user/106643870/chris-norfolk')
# (545, 'https://www.mountainproject.com/user/106743355/incha')
# (546, 'https://www.mountainproject.com/user/106748471/alex-washburne')
# (547, 'https://www.mountainproject.com/user/106985791/jaysen-henderson')
# (548, 'https://www.mountainproject.com/user/106855118/alicia-sokolowski')
# (549, 'https://www.mountainproject.com/user/106853948/justin-johnsen')
# (550, 'https://www.mountainproject.com/user/106430712/zachary-w')
# (551, 'https://www.mountainproject.com/user/106554048/barrett-stetson')
# (552, 'https://www.mountainproject.com/user/106580951/jlam-lamason')
# (553, 'https://www.mountainproject.com/user/107238223/tony-lopez')
# (554, 'https://www.mountainproject.com/user/107395144/w-jerome-smyth')
# (555, 'https://www.mountainproject.com/user/106719962/crossing')
# (556, 'https://www.mountainproject.com/user/107817828/turbotime')
# (557, 'https://www.mountainproject.com/user/107178254/alex-cv')
# (558, 'https://www.mountainproject.com/user/108082584/alec-orenstein')
# (559, 'https://www.mountainproject.com/user/106579529/john-patrick')
# (560, 'https://www.mountainproject.com/user/107746328/gio92')
# (561, 'https://www.mountainproject.com/user/107304112/alibierc')
# (562, 'https://www.mountainproject.com/user/108073727/sean-patrick-nyc')
# (563, 'https://www.mountainproject.com/user/107224041/drew-hayes')
# (564, 'https://www.mountainproject.com/user/108104464/armoss')
# (565, 'https://www.mountainproject.com/user/107923020/sherb')
# (566, 'https://www.mountainproject.com/user/107807462/tml')
# (567, 'https://www.mountainproject.com/user/107819171/kyle-gilstrap')
# (568, 'https://www.mountainproject.com/user/108007498/paul-h')
# (569, 'https://www.mountainproject.com/user/108293163/sobehr-behr')
# (570, 'https://www.mountainproject.com/user/107373999/spencer-nowak')
# (571, 'https://www.mountainproject.com/user/108334824/trey-bell')
# (572, 'https://www.mountainproject.com/user/108336210/ben-beck-coon')
# (573, 'https://www.mountainproject.com/user/108297021/steve-minn')
# (574, 'https://www.mountainproject.com/user/106956714/ridethejoy')
# (575, 'https://www.mountainproject.com/user/108398786/jaron1729')
# (576, 'https://www.mountainproject.com/user/108124265/ahp')
# (577, 'https://www.mountainproject.com/user/109856888/john-pikus')
# (578, 'https://www.mountainproject.com/user/107625137/nate-kempner')
# (579, 'https://www.mountainproject.com/user/108476315/avi-b')
# (580, 'https://www.mountainproject.com/user/108495695/molly-bremner')
# (581, 'https://www.mountainproject.com/user/108711756/aaron-lizor')
# (582, 'https://www.mountainproject.com/user/108201220/d-l')
# (583, 'https://www.mountainproject.com/user/107640541/cj-k')
# (584, 'https://www.mountainproject.com/user/106022427/jeffrey-dunn')
# (585, 'https://www.mountainproject.com/user/106449525/christopher-payan')
# (586, 'https://www.mountainproject.com/user/108652563/jon-dawood')
# (587, 'https://www.mountainproject.com/user/107134664/giroy')
# (588, 'https://www.mountainproject.com/user/108298258/bowzer')
# (589, 'https://www.mountainproject.com/user/108099571/scott-taber')
# (590, 'https://www.mountainproject.com/user/107768989/byron-igoe')
# (591, 'https://www.mountainproject.com/user/107248365/theicemancometh')
# (592, 'https://www.mountainproject.com/user/108354123/nick-knoke')
# (593, 'https://www.mountainproject.com/user/109289720/howie-meivogel')
# (594, 'https://www.mountainproject.com/user/108118109/rhondita')
# (595, 'https://www.mountainproject.com/user/105911703/matt-walker')
# (596, 'https://www.mountainproject.com/user/106486112/twellman')
# (597, 'https://www.mountainproject.com/user/108710934/david-kendall')
# (598, 'https://www.mountainproject.com/user/108759814/nate-iv')
# (599, 'https://www.mountainproject.com/user/108867086/ashley-c')
# (600, 'https://www.mountainproject.com/user/106539537/andy-thien')
# (601, 'https://www.mountainproject.com/user/108905794/brochacho')
# (602, 'https://www.mountainproject.com/user/106653468/matt-baer')
# (603, 'https://www.mountainproject.com/user/107116332/connor-newman')
# (604, 'https://www.mountainproject.com/user/109586132/dasaan')
# (605, 'https://www.mountainproject.com/user/109585728/daphne')
# (606, 'https://www.mountainproject.com/user/107674835/blakecollins')
# (607, 'https://www.mountainproject.com/user/106879280/dan-wachlaczenko')
# (608, 'https://www.mountainproject.com/user/109627755/ajsnyder')
# (609, 'https://www.mountainproject.com/user/108098921/john-wagner')
# (610, 'https://www.mountainproject.com/user/109437284/kimberley-rothacker')
# (611, 'https://www.mountainproject.com/user/107699335/jamint')
# (612, 'https://www.mountainproject.com/user/109525957/jon-zorella')
# (613, 'https://www.mountainproject.com/user/109816235/nth')
# (614, 'https://www.mountainproject.com/user/108805745/cedric-bg')
# (615, 'https://www.mountainproject.com/user/107417154/aaron-johnston')
# (616, 'https://www.mountainproject.com/user/109563509/lotte-meijer')
# (617, 'https://www.mountainproject.com/user/108981414/matt-vega')
# (618, 'https://www.mountainproject.com/user/109316126/cjmaynar')
# (619, 'https://www.mountainproject.com/user/106978809/ben-smith')
# (620, 'https://www.mountainproject.com/user/109405787/danielle-lansford')
# (621, 'https://www.mountainproject.com/user/108265416/sigg')
# (622, 'https://www.mountainproject.com/user/108272772/ryan-c')
# (623, 'https://www.mountainproject.com/user/105886625/eric-beyeler')
# (624, 'https://www.mountainproject.com/user/107097698/phil-tatti')
# (625, 'https://www.mountainproject.com/user/107801617/dylan-randall')
# (626, 'https://www.mountainproject.com/user/108110667/agennis')
# (627, 'https://www.mountainproject.com/user/109193524/matt-greenberg')
# (628, 'https://www.mountainproject.com/user/105826579/john-evans')
# (629, 'https://www.mountainproject.com/user/107970005/michele-evans')
# (630, 'https://www.mountainproject.com/user/106107825/david-kider')
# (631, 'https://www.mountainproject.com/user/110998345/jessica-pizzillo')
# (632, 'https://www.mountainproject.com/user/107002071/bababata')
# (633, 'https://www.mountainproject.com/user/107646553/k-baumgartner')
# (634, 'https://www.mountainproject.com/user/110320894/rox')
# (635, 'https://www.mountainproject.com/user/111169936/wendi-yoakum')
# (636, 'https://www.mountainproject.com/user/108731818/yvonneyz')
# (637, 'https://www.mountainproject.com/user/110619029/molly-zhu')
# (638, 'https://www.mountainproject.com/user/110972188/steve-adams')
# (639, 'https://www.mountainproject.com/user/106717383/chipacles')
# (640, 'https://www.mountainproject.com/user/111581476/stewart-barlow')
# (641, 'https://www.mountainproject.com/user/107606573/dan-mccracken')
# (642, 'https://www.mountainproject.com/user/108633199/mattd1881')
# (643, 'https://www.mountainproject.com/user/111815674/joshua-shockley')
# (644, 'https://www.mountainproject.com/user/111821221/voice-of-reason')
# (645, 'https://www.mountainproject.com/user/110462006/sammyastra')
# (646, 'https://www.mountainproject.com/user/111089776/blakeh')
# (647, 'https://www.mountainproject.com/user/111281190/aaron-dlo')
# (648, 'https://www.mountainproject.com/user/109548191/isara')
# (649, 'https://www.mountainproject.com/user/105892608/bruce-lacroix')
# (650, 'https://www.mountainproject.com/user/108252197/petr07-lindahl')
# (651, 'https://www.mountainproject.com/user/107561580/pspoutz-spoutz')
# (652, 'https://www.mountainproject.com/user/111841723/nathaniel-chu')
# (653, 'https://www.mountainproject.com/user/111955057/meghan-molloy')
# (654, 'https://www.mountainproject.com/user/112039304/flora-leonard')
# (655, 'https://www.mountainproject.com/user/110315255/james-donigan')
# (656, 'https://www.mountainproject.com/user/109086735/afrongillo')
# (657, 'https://www.mountainproject.com/user/110547878/zabain')
# (658, 'https://www.mountainproject.com/user/110635583/evan-nece')
# (659, 'https://www.mountainproject.com/user/106210225/eric-bluemn')
# (660, 'https://www.mountainproject.com/user/109465165/matt-patterson')
# (661, 'https://www.mountainproject.com/user/108320578/tpitts')
# (662, 'https://www.mountainproject.com/user/110946269/bradley-gorsline')
# (663, 'https://www.mountainproject.com/user/112166649/jason-charles')
# (664, 'https://www.mountainproject.com/user/112097145/ed-keller')
# (665, 'https://www.mountainproject.com/user/111983604/acmesalute76')
# (666, 'https://www.mountainproject.com/user/109737113/andrew-kontola')
# (667, 'https://www.mountainproject.com/user/107119283/martin-bennett')
# (668, 'https://www.mountainproject.com/user/105794390/marc-rosenthal')
# (669, 'https://www.mountainproject.com/user/111744118/thescendant')
# (670, 'https://www.mountainproject.com/user/111850994/bridge')
# (671, 'https://www.mountainproject.com/user/111685114/paul-dlug')
# (672, 'https://www.mountainproject.com/user/112285206/kimberly-blakemore')
# (673, 'https://www.mountainproject.com/user/109414386/jesse-bryant')
# (674, 'https://www.mountainproject.com/user/110839245/elliott-becker')
# (675, 'https://www.mountainproject.com/user/108543998/mark-sudak')
# (676, 'https://www.mountainproject.com/user/111854190/simon-bloch')
# (677, 'https://www.mountainproject.com/user/110425509/b-l')
# (678, 'https://www.mountainproject.com/user/112474279/rockie-welp')
# (679, 'https://www.mountainproject.com/user/107700110/gregory-kanter')
# (680, 'https://www.mountainproject.com/user/108911162/eric-nguyen')
# (681, 'https://www.mountainproject.com/user/111348762/sean-phillips')
# (682, 'https://www.mountainproject.com/user/108121411/andrew-tong')
# (683, 'https://www.mountainproject.com/user/108772391/matt-mccaslin')
# (684, 'https://www.mountainproject.com/user/108363902/andrew-d-wong')
# (685, 'https://www.mountainproject.com/user/112412061/ted-n')
# (686, 'https://www.mountainproject.com/user/111657384/david')
# (687, 'https://www.mountainproject.com/user/112946306/alannah-joyce')
# (688, 'https://www.mountainproject.com/user/112352056/mherzog')
# (689, 'https://www.mountainproject.com/user/111824829/philippe-cossette')
# (690, 'https://www.mountainproject.com/user/107380650/dave-leydet')
# (691, 'https://www.mountainproject.com/user/200123489/natasha-collins')
# (692, 'https://www.mountainproject.com/user/112239612/robert-liu')
# (693, 'https://www.mountainproject.com/user/111796230/mac-weiler')
# (694, 'https://www.mountainproject.com/user/108446880/markbust')
# (695, 'https://www.mountainproject.com/user/112233000/christopher-wallin')
# (696, 'https://www.mountainproject.com/user/200146852/hannibal-l')
# (697, 'https://www.mountainproject.com/user/109895944/burton7')
# (698, 'https://www.mountainproject.com/user/109778651/tali-gutman')
# (699, 'https://www.mountainproject.com/user/112004901/ben-kleiman')
# (700, 'https://www.mountainproject.com/user/112070569/david-postelt')
# (701, 'https://www.mountainproject.com/user/200085165/vincent-blouin')
# (702, 'https://www.mountainproject.com/user/112102872/tuckercowles')
# (703, 'https://www.mountainproject.com/user/107569651/lauren-littleredclimbinghood')
# (704, 'https://www.mountainproject.com/user/112480961/john-berry')
# (705, 'https://www.mountainproject.com/user/111999314/bamdali')
# (706, 'https://www.mountainproject.com/user/108225547/shane-kenyon')
# (707, 'https://www.mountainproject.com/user/112042073/adam-hammershoi')
# (708, 'https://www.mountainproject.com/user/7117171/kyle-espinosa')
# (709, 'https://www.mountainproject.com/user/112124162/kyle-espinosa')
# (710, 'https://www.mountainproject.com/user/200041551/sax-max')
# ...
# (2200, 'https://www.mountainproject.com/user/109384124/will-carney')
# (2201, 'https://www.mountainproject.com/user/112001335/jon-nic')
# (2202, 'https://www.mountainproject.com/user/111875700/enrique-bascur')
# (2203, 'https://www.mountainproject.com/user/110231237/socotra')
# (2204, 'https://www.mountainproject.com/user/112053406/ryan-ciccone')
# (2205, 'https://www.mountainproject.com/user/107016978/mike-a-lewis')
# (2206, 'https://www.mountainproject.com/user/112109412/jesse-wild')
# (2207, 'https://www.mountainproject.com/user/108104088/jordan-kessler')
# (2208, 'https://www.mountainproject.com/user/111856713/adi-azulay')
# (2209, 'https://www.mountainproject.com/user/106058175/tom-drewes')
# (2210, 'https://www.mountainproject.com/user/111569050/jeff-crawford')
# (2211, 'https://www.mountainproject.com/user/107926361/preston-rhea')
# (2212, 'https://www.mountainproject.com/user/112215900/kathleen-yan')
# (2213, 'https://www.mountainproject.com/user/105787679/mike-c')
# (2214, 'https://www.mountainproject.com/user/10188/ross-swanson')
# (2215, 'https://www.mountainproject.com/user/108207789/archimatect')
# (2216, 'https://www.mountainproject.com/user/109329058/jotto')
# (2217, 'https://www.mountainproject.com/user/107560545/seth-maciejowski')
# (2218, 'https://www.mountainproject.com/user/112549045/michael-coody')
# (2219, 'https://www.mountainproject.com/user/112104441/paul-macgregor')
# (2220, 'https://www.mountainproject.com/user/105989861/curvenut')
# (2221, 'https://www.mountainproject.com/user/109048457/matt-thomsen')
# (2222, 'https://www.mountainproject.com/user/109411863/jmicher')
# (2223, 'https://www.mountainproject.com/user/111214144/sab160')
# (2224, 'https://www.mountainproject.com/user/200054131/katie-dilts')
# (2225, 'https://www.mountainproject.com/user/112111814/john-demers')
# (2226, 'https://www.mountainproject.com/user/111624894/kevin-stewart')
# (2227, 'https://www.mountainproject.com/user/107297115/ccanez')
# (2228, 'https://www.mountainproject.com/user/107954393/devo86-waters')
# (2229, 'https://www.mountainproject.com/user/111618723/thomas-garatina')
# (2230, 'https://www.mountainproject.com/user/200063620/nicholas-mitchell')
# (2231, 'https://www.mountainproject.com/user/110875851/smarten')
# (2232, 'https://www.mountainproject.com/user/112137702/adam-hart')
# (2233, 'https://www.mountainproject.com/user/108430429/camilo-casas')
# (2234, 'https://www.mountainproject.com/user/106686976/marc-daubert')
# (2235, 'https://www.mountainproject.com/user/111948666/adam-hannibal')
# (2236, 'https://www.mountainproject.com/user/111429574/james-westy')
# (2237, 'https://www.mountainproject.com/user/111935081/jklobato')
# (2238, 'https://www.mountainproject.com/user/108654631/davg99')
# (2239, 'https://www.mountainproject.com/user/105818656/jon-jugenheimer')
# (2240, 'https://www.mountainproject.com/user/107772805/grog-m')
# (2241, 'https://www.mountainproject.com/user/108475529/maddee-r')
# (2242, 'https://www.mountainproject.com/user/107995447/bart-kensinger')
# (2243, 'https://www.mountainproject.com/user/111571092/becca-simeone')
# (2244, 'https://www.mountainproject.com/user/110566896/nick-esker')
# (2245, 'https://www.mountainproject.com/user/200160322/jared-hancock')
# (2246, 'https://www.mountainproject.com/user/112050804/jon-curtiss')
# (2247, 'https://www.mountainproject.com/user/110725284/marco-munizaga')
# (2248, 'https://www.mountainproject.com/user/109141670/dillon-metcalfe-1')
# (2249, 'https://www.mountainproject.com/user/105787467/chris-sheridan')
# (2250, 'https://www.mountainproject.com/user/112445912/andrew-holman')
# (2251, 'https://www.mountainproject.com/user/111838614/sean-haggerty')
# (2252, 'https://www.mountainproject.com/user/109878388/botao-hu')
# (2253, 'https://www.mountainproject.com/user/112520960/jimmy-bricker')
# (2254, 'https://www.mountainproject.com/user/200150170/molly-may')
# (2255, 'https://www.mountainproject.com/user/105802459/gina-hoag')
# (2256, 'https://www.mountainproject.com/user/111488411/nathan-sick')
# (2257, 'https://www.mountainproject.com/user/112318234/dan-horton')
# (2258, 'https://www.mountainproject.com/user/200229522/kevin-mccartney')
# (2259, 'https://www.mountainproject.com/user/111700011/david-cain')
# (2260, 'https://www.mountainproject.com/user/112783536/elias-stuhr')
# (2261, 'https://www.mountainproject.com/user/107866588/james-e')
# (2262, 'https://www.mountainproject.com/user/109101477/joel-geerling')
# (2263, 'https://www.mountainproject.com/user/200012488/corey-b')
# (2264, 'https://www.mountainproject.com/user/200336273/lisa-madden')
# (2265, 'https://www.mountainproject.com/user/112207022/jessie-briggs')
# (2266, 'https://www.mountainproject.com/user/200337119/jonathan-feldschuh')
# (2267, 'https://www.mountainproject.com/user/105084340/brian-treanor')
# (2268, 'https://www.mountainproject.com/user/108689765/kyle-poole')
# (2269, 'https://www.mountainproject.com/user/200340278/austin-morris')
# (2270, 'https://www.mountainproject.com/user/200321215/jon-bielik')
# (2271, 'https://www.mountainproject.com/user/111453616/olivier-lafontaine-gariepy')
# (2272, 'https://www.mountainproject.com/user/200345202/israel-halle')
# (2273, 'https://www.mountainproject.com/user/200355733/john-schneider')
# (2274, 'https://www.mountainproject.com/user/109004880/jo-sarago')
# (2275, 'https://www.mountainproject.com/user/112000990/adam-tobey')
# (2276, 'https://www.mountainproject.com/user/200211565/kennedy-carey')
# (2277, 'https://www.mountainproject.com/user/105878349/geoffrey-kinsey')
# (2278, 'https://www.mountainproject.com/user/14073/tom-kelley')
# (2279, 'https://www.mountainproject.com/user/107314708/johnny-utah')
# (2280, 'https://www.mountainproject.com/user/111882825/oscar-sandoval')
# (2281, 'https://www.mountainproject.com/user/200375476/antonia-lister')
# (2282, 'https://www.mountainproject.com/user/111845712/owen-silitch')
# (2283, 'https://www.mountainproject.com/user/107166204/kemple-sr')
# (2284, 'https://www.mountainproject.com/user/110996540/dan-earhart')
# (2285, 'https://www.mountainproject.com/user/200163137/nick-haha')
# (2286, 'https://www.mountainproject.com/user/200184778/dana-daner')
# (2287, 'https://www.mountainproject.com/user/105978997/s-stember')
# (2288, 'https://www.mountainproject.com/user/111970290/ian-murashige')
# (2289, 'https://www.mountainproject.com/user/200399257/marcello-cricco-lizza')
# (2290, 'https://www.mountainproject.com/user/112496934/jesse-vanek')
# (2291, 'https://www.mountainproject.com/user/106376808/jill-north-wilson')
# (2292, 'https://www.mountainproject.com/user/112026181/kristinicole')
# (2293, 'https://www.mountainproject.com/user/106000626/brianup-up')
# (2294, 'https://www.mountainproject.com/user/105830665/ralph-kolva')
# (2295, 'https://www.mountainproject.com/user/10359/leo-paik')
# (2296, 'https://www.mountainproject.com/user/106714105/stevendo')
# (2297, 'https://www.mountainproject.com/user/106068274/ryan-hunt')
# (2298, 'https://www.mountainproject.com/user/107284917/tessa-o')
# (2299, 'https://www.mountainproject.com/user/108184331/alexis-wojtanowski')
# (2300, 'https://www.mountainproject.com/user/109081636/eberliner')
# (2301, 'https://www.mountainproject.com/user/106043351/hans')
# (2302, 'https://www.mountainproject.com/user/110518966/sonya-st-john')
# (2303, 'https://www.mountainproject.com/user/107729190/inferno-tommey')
# (2304, 'https://www.mountainproject.com/user/106589820/brook-wager')
# (2305, 'https://www.mountainproject.com/user/110690083/kevin-omally')
# (2306, 'https://www.mountainproject.com/user/107010283/grant-gibson')
# (2307, 'https://www.mountainproject.com/user/105841142/kzoo')
# (2308, 'https://www.mountainproject.com/user/110512719/daniel-rossi-1')
# (2309, 'https://www.mountainproject.com/user/106548211/joe-castellano')
# (2310, 'https://www.mountainproject.com/user/106816785/dustin-stephens')
# (2311, 'https://www.mountainproject.com/user/109598845/joseph-mcgrath')
# (2312, 'https://www.mountainproject.com/user/200037478/justin-viles')
# (2313, 'https://www.mountainproject.com/user/110904912/matt-skorina')
# (2314, 'https://www.mountainproject.com/user/106577584/baldy')
# (2315, 'https://www.mountainproject.com/user/107131979/seth-hogan')
# (2316, 'https://www.mountainproject.com/user/200272385/howie-meivogel')
# (2317, 'https://www.mountainproject.com/user/200211168/josh-rymer')
# (2318, 'https://www.mountainproject.com/user/200327938/carmen-labbe')
# (2319, 'https://www.mountainproject.com/user/12145/wes-turner')
# (2320, 'https://www.mountainproject.com/user/112278406/bitchinfromdagunks')
# (2321, 'https://www.mountainproject.com/user/111733036/luna-luna')
# (2322, 'https://www.mountainproject.com/user/106400151/kurt-ross')
# (2323, 'https://www.mountainproject.com/user/108692739/marc801-c')
# (2324, 'https://www.mountainproject.com/user/109355903/elvis-kucevic')
# (2325, 'https://www.mountainproject.com/user/107060717/sylvia')
# (2326, 'https://www.mountainproject.com/user/106415384/michael-besten')
# (2327, 'https://www.mountainproject.com/user/111189100/walker-bockley')
# (2328, 'https://www.mountainproject.com/user/111466290/adam-maslar')
# (2329, 'https://www.mountainproject.com/user/200124208/jon-rust')
# (2330, 'https://www.mountainproject.com/user/110587802/eayermann')
# (2331, 'https://www.mountainproject.com/user/106691364/rgb76')
# (2332, 'https://www.mountainproject.com/user/106662032/ross-weller')
# (2333, 'https://www.mountainproject.com/user/108091672/ckersch')
# (2334, 'https://www.mountainproject.com/user/109272971/jake-starr')
# (2335, 'https://www.mountainproject.com/user/111538784/suz-zak')
# (2336, 'https://www.mountainproject.com/user/106300256/fat-paul')
# (2337, 'https://www.mountainproject.com/user/107607301/alex-mitchell')
# (2338, 'https://www.mountainproject.com/user/106280993/eli-fierer')
# (2339, 'https://www.mountainproject.com/user/106779960/steven-cherry')
# (2340, 'https://www.mountainproject.com/user/106781531/focus')
# (2341, 'https://www.mountainproject.com/user/106917666/todd-townsend')
# (2342, 'https://www.mountainproject.com/user/107980100/jackie-sanford')
# (2343, 'https://www.mountainproject.com/user/111978145/maine-chaisarn')
# (2344, 'https://www.mountainproject.com/user/109639188/kylepeet')
# (2345, 'https://www.mountainproject.com/user/11409/aj')
# (2346, 'https://www.mountainproject.com/user/111047210/stefan-nagy8')
# (2347, 'https://www.mountainproject.com/user/108386304/sergeid-didur')
# (2348, 'https://www.mountainproject.com/user/109431524/kris-fiore')
# (2349, 'https://www.mountainproject.com/user/105887092/greg-mionske')
# (2350, 'https://www.mountainproject.com/user/106610440/jon-h')
# (2351, 'https://www.mountainproject.com/user/106964062/aisha')
# (2352, 'https://www.mountainproject.com/user/106190364/jon-cheifitz')
# (2353, 'https://www.mountainproject.com/user/105885115/m-sprague')
# (2354, 'https://www.mountainproject.com/user/108915729/katisthebatis')
# (2355, 'https://www.mountainproject.com/user/108896288/jayctclimber')
# (2356, 'https://www.mountainproject.com/user/108760211/andrewww')
# (2357, 'https://www.mountainproject.com/user/200132716/eyahnu-adela')
# (2358, 'https://www.mountainproject.com/user/108076264/bigred11')
# (2359, 'https://www.mountainproject.com/user/106887732/john-douglass')
# (2360, 'https://www.mountainproject.com/user/200215572/john-yaworsky')
# (2361, 'https://www.mountainproject.com/user/106843929/kevin-kent')
# (2362, 'https://www.mountainproject.com/user/106835670/greg-t')
# (2363, 'https://www.mountainproject.com/user/7117348/james-ortmann')
# (2364, 'https://www.mountainproject.com/user/110859195/dwight-l')
# (2365, 'https://www.mountainproject.com/user/108587373/max-dismukes')
# (2366, 'https://www.mountainproject.com/user/107633023/david-cooper')
# (2367, 'https://www.mountainproject.com/user/110686557/cristian-montoya')
# (2368, 'https://www.mountainproject.com/user/108535796/marco-dees')
# (2369, 'https://www.mountainproject.com/user/105791468/scherry')
# (2370, 'https://www.mountainproject.com/user/109201170/brianszero')
# (2371, 'https://www.mountainproject.com/user/106142908/andy-mcadams')
# (2372, 'https://www.mountainproject.com/user/107340553/chadd-sechler')
# (2373, 'https://www.mountainproject.com/user/108053439/krich')
# (2374, 'https://www.mountainproject.com/user/105888095/joe-mucci')
# (2375, 'https://www.mountainproject.com/user/108223598/doug-rosenberg')
# (2376, 'https://www.mountainproject.com/user/108029460/moritz-b')
# (2377, 'https://www.mountainproject.com/user/109255473/guy-bresler')
# (2378, 'https://www.mountainproject.com/user/105788876/alex-shainman')
# (2379, 'https://www.mountainproject.com/user/200204185/lewis-pratt')
# (2380, 'https://www.mountainproject.com/user/110974574/kyle-ondy')
# (2381, 'https://www.mountainproject.com/user/109058226')
# (2382, 'https://www.mountainproject.com/user/106981430/kevin-johnson')
# (2383, 'https://www.mountainproject.com/user/106306412/justin-marquis')
# (2384, 'https://www.mountainproject.com/user/105996592/john-steiger')
# (2385, 'https://www.mountainproject.com/user/109638036/wes-j')
# (2386, 'https://www.mountainproject.com/user/200219877/j-gills')
# (2387, 'https://www.mountainproject.com/user/110292774/moreannefrank')
# (2388, 'https://www.mountainproject.com/user/107561202/jonathon-esack')
# (2389, 'https://www.mountainproject.com/user/111114467/joe-davis')
# (2390, 'https://www.mountainproject.com/user/107303788/jsw')
# (2391, 'https://www.mountainproject.com/user/108436633/sleyer')
# (2392, 'https://www.mountainproject.com/user/106680253/georgejessel')
# (2393, 'https://www.mountainproject.com/user/112060462/james-gray')
# (2394, 'https://www.mountainproject.com/user/107200455/gravity-slave')
# (2395, 'https://www.mountainproject.com/user/109229283/lothian-buss')
# (2396, 'https://www.mountainproject.com/user/110957596/nicolas-falacci')
# (2397, 'https://www.mountainproject.com/user/107217635/rm11')
# (2398, 'https://www.mountainproject.com/user/107204494/nartreb')
# (2399, 'https://www.mountainproject.com/user/200152315/alex-billings')
# (2400, 'https://www.mountainproject.com/user/200154262/max-hernandez')
# (2401, 'https://www.mountainproject.com/user/106392257/kg-lee')
# (2402, 'https://www.mountainproject.com/user/200164626/austin-e')
# (2403, 'https://www.mountainproject.com/user/108106813/jenna-bostock')
# (2404, 'https://www.mountainproject.com/user/200256729/olivia-ellard')
# (2405, 'https://www.mountainproject.com/user/200141367/luke-andraka')
# (2406, 'https://www.mountainproject.com/user/109367148/ross-ladley')
# (2407, 'https://www.mountainproject.com/user/200300065/meg-chow')
# (2408, 'https://www.mountainproject.com/user/106055414/mike-morin')
# (2409, 'https://www.mountainproject.com/user/109740864/ryanmullins')
# (2410, 'https://www.mountainproject.com/user/106319582/treker')
# (2411, 'https://www.mountainproject.com/user/106935843/will-adsit')
# (2412, 'https://www.mountainproject.com/user/108132717/aharlec')
# (2413, 'https://www.mountainproject.com/user/108373969/hannah-tuttle')
# (2414, 'https://www.mountainproject.com/user/112843735/chris-kocher')
# (2415, 'https://www.mountainproject.com/user/110687338/ian-mcmullen')
# (2416, 'https://www.mountainproject.com/user/107595240/kellen-j')
# (2417, 'https://www.mountainproject.com/user/110802936/arthur-torrey')
# (2418, 'https://www.mountainproject.com/user/105870073/jordan-k')
# (2419, 'https://www.mountainproject.com/user/12291/jamie-givens')
# (2420, 'https://www.mountainproject.com/user/106298729/k-man')
# (2421, 'https://www.mountainproject.com/user/107550300/david-raines')
# (2422, 'https://www.mountainproject.com/user/108156601/steven-scr')
# (2423, 'https://www.mountainproject.com/user/108867265/kristian-starheim')
# (2424, 'https://www.mountainproject.com/user/111710323/jack-thoene')
# (2425, 'https://www.mountainproject.com/user/110374930/cooper-c')
# (2426, 'https://www.mountainproject.com/user/109619862/reevesh-hollar')
# (2427, 'https://www.mountainproject.com/user/200141719/charlie-schmidt')
# (2428, 'https://www.mountainproject.com/user/108206585/jack13')
# (2429, 'https://www.mountainproject.com/user/112146574/austin-edwards')
# (2430, 'https://www.mountainproject.com/user/113002346/brian-slepian')
# (2431, 'https://www.mountainproject.com/user/110997585/mark-berenblum')

# %% [markdown]
# # Add uid and iid to route_ratings.csv

# %%
route_data_file = '../data/route_data.csv'
df_routes = pd.read_csv(route_data_file)

ratings_file = '../data/route_ratings.csv'
df_ratings = pd.read_csv(ratings_file)

user_data_file = '../data/user_data.csv'
df_users = pd.read_csv(user_data_file)

# Start with the ratings table.
# Add the iid
df = df_ratings.merge(df_routes[['iid', 'route_url']], on='route_url', how='inner')
# Add the uid
df = df.merge(df_users[['uid', 'user_url']], on='user_url', how='inner')
# Sort for readability
df = df.sort_values(['iid', 'uid'])

# Save the new ratings file
df[['iid', 'uid', 'rating', 'route_url', 'user_url']].to_csv('../data/route_ratings_merged.csv', index=False, encoding='utf-8')

# %%
display(df_ratings.head())
display(df.head())
# Out:
#    rating                                                     route_url  \
# 0       2  https://www.mountainproject.com/route/108300801/sudoriferous
# 1       2  https://www.mountainproject.com/route/108300801/sudoriferous
# 2       2  https://www.mountainproject.com/route/108300801/sudoriferous
# 3       1  https://www.mountainproject.com/route/108300801/sudoriferous
# 4       1  https://www.mountainproject.com/route/108300801/sudoriferous
#
#                                                      user_url
# 0    https://www.mountainproject.com/user/106087077/mark-roth
# 1    https://www.mountainproject.com/user/109581184/joel-ryan
# 2  https://www.mountainproject.com/user/200223567/anyo-lesiuk
# 3      https://www.mountainproject.com/user/107253738/dragons
# 4    https://www.mountainproject.com/user/106630260/j-serpico
#      rating                                                     route_url  \
# 0         2  https://www.mountainproject.com/route/108300801/sudoriferous
# 142       2  https://www.mountainproject.com/route/108300801/sudoriferous
# 218       2  https://www.mountainproject.com/route/108300801/sudoriferous
# 224       1  https://www.mountainproject.com/route/108300801/sudoriferous
# 248       1  https://www.mountainproject.com/route/108300801/sudoriferous
#
#                                                        user_url  iid  uid
# 0      https://www.mountainproject.com/user/106087077/mark-roth    0    0
# 142    https://www.mountainproject.com/user/109581184/joel-ryan    0    1
# 218  https://www.mountainproject.com/user/200223567/anyo-lesiuk    0    2
# 224      https://www.mountainproject.com/user/107253738/dragons    0    3
# 248    https://www.mountainproject.com/user/106630260/j-serpico    0    4
